# %%
# !pip install crossrefapi
# !pip install orcid
# Out:
# Requirement already satisfied: crossrefapi in /usr/local/lib/python3.12/dist-packages (1.7.0)
# Requirement already satisfied: ipython<9.0.0,>=8.28.0 in /usr/local/lib/python3.12/dist-packages (from crossrefapi) (8.37.0)
# Requirement already satisfied: requests<3.0.0,>=2.32.3 in /usr/local/lib/python3.12/dist-packages (from crossrefapi) (2.32.4)
# Requirement already satisfied: urllib3<3.0.0,>=2.2.3 in /usr/local/lib/python3.12/dist-packages (from crossrefapi) (2.5.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.12/dist-packages (from ipython<9.0.0,>=8.28.0->crossrefapi) (4.4.2)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.12/dist-packages (from ipython<9.0.0,>=8.28.0->crossrefapi) (0.19.2)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.12/dist-packages (from ipython<9.0.0,>=8.28.0->crossrefapi) (0.2.1)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.12/dist-packages (from ipython<9.0.0,>=8.28.0->crossrefapi) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /usr/local/lib/python3.12/dist-packages (from ipython<9.0.0,>=8.28.0->crossrefapi) (3.0.52)
# Requirement already satisfied: pygments>=2.4.0 in /usr/local/lib/python3.12/dist-packages (from ipython<9.0.0,>=8.28.0->crossrefapi) (2.19.2)
# Requirement already satisfied: stack_data in /usr/local/lib/python3.12/dist-packages (from ipython<9.0.0,>=8.28.0->crossrefapi) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in /usr/local/lib/python3.12/dist-packages (from ipython<9.0.0,>=8.28.0->crossrefapi) (5.14.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.3->crossrefapi) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.3->crossrefapi) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.3->crossrefapi) (2025.11.12)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.12/dist-packages (from jedi>=0.16->ipython<9.0.0,>=8.28.0->crossrefapi) (0.8.5)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.12/dist-packages (from pexpect>4.3->ipython<9.0.0,>=8.28.0->crossrefapi) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython<9.0.0,>=8.28.0->crossrefapi) (0.2.14)
# Requirement already satisfied: executing>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from stack_data->ipython<9.0.0,>=8.28.0->crossrefapi) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /usr/local/lib/python3.12/dist-packages (from stack_data->ipython<9.0.0,>=8.28.0->crossrefapi) (3.0.1)
# Requirement already satisfied: pure-eval in /usr/local/lib/python3.12/dist-packages (from stack_data->ipython<9.0.0,>=8.28.0->crossrefapi) (0.2.3)
# Collecting orcid
#   Using cached orcid-1.0.3.tar.gz (10 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: html5lib in /usr/local/lib/python3.12/dist-packages (from orcid) (1.1)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (from orcid) (4.13.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from orcid) (2.32.4)
# Requirement already satisfied: simplejson in /usr/local/lib/python3.12/dist-packages (from orcid) (3.20.2)
# Requirement already satisfied: lxml in /usr/local/lib/python3.12/dist-packages (from orcid) (6.0.2)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->orcid) (2.8)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->orcid) (4.15.0)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.12/dist-packages (from html5lib->orcid) (1.17.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.12/dist-packages (from html5lib->orcid) (0.5.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->orcid) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->orcid) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->orcid) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->orcid) (2025.11.12)
# Building wheels for collected packages: orcid
#   Building wheel for orcid (setup.py) ... done
#   Created wheel for orcid: filename=orcid-1.0.3-py3-none-any.whl size=10443 sha256=abca2eb2f57617ad612d26060a5ea2d749b9039fb9613bedd90be3cf34a35163
#   Stored in directory: /root/.cache/pip/wheels/77/97/ed/c29a05c6a5bfde56e7adbfa37dea18a6bb08a27241ba0a7dcc
# Successfully built orcid
# Installing collected packages: orcid
# Successfully installed orcid-1.0.3

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# # Journal tuples

# %%
# helpers to serialize the text
import math

def sql_literal(value):
    if value is None:
        return "NULL"
    if isinstance(value, float) and math.isnan(value):
        return "NULL"
    if isinstance(value, str):
        return "'" + value.replace("'", "''") + "'"
    return str(value)

import re

def normalize(s: str) -> str:
    if s is None:
        return s

    s = (
        s.replace("’", "'")      # curly single quote
         .replace("‘", "'")      # curly single quote
         .replace("‐", "-")      # unicode hyphen
         .replace("–", "-")      # en dash (U+2013)
         .replace("—", "-")      # em dash (U+2014)
    )

    # collapse multiple spaces
    s = re.sub(r"\s+", " ", s)

    return s.strip()

# %%
# Journal files pulled as CSV and converted to tsv from here: https://jcr-clarivate-com.proxy1.library.jhu.edu/jcr/browse-journals
journal_list="/content/drive/MyDrive/databases_project/journal_impact_factor.tsv"
top_10={}
with open(journal_list, 'r') as file:
    # Skip first header lines
    for i in range(0,2):
        file.readline()
    columns=[item.strip().strip('"') for item in file.readline().strip().strip('"').split("\t")]
    for n in range(0,10):
        journal=[item.strip().strip('"') for item in file.readline().strip().strip('"').split("\t")]
        top_10[journal[0]]=dict(zip(columns[1:], journal[1:]))

# %%
journal_issns=[]
with open("journal_tuples.txt", "w") as j:
    for journal_name in top_10.keys():
        journal_values = [journal_name] # Add the full journal name (key of top_10) once
        # Collect values for the current journal from its inner dictionary, excluding the 'Journal name' entry
        for key in top_10[journal_name].keys():
            if key != 'Journal name': # This key holds the abbreviated name, causing the duplication
                journal_values.append(top_10[journal_name][key])
        # Convert the list of strings to a tuple, then to its string representation, and add a newline
        values_sql = "(" + ", ".join(sql_literal(v) for v in journal_values) + ")"
        j.write(
            f"INSERT INTO Journals VALUES {values_sql} "
            "ON CONFLICT (LongName) DO NOTHING;\n"
        )

# %%
publishers = set()
for journal_name in top_10.keys():
    publishers.add(top_10[journal_name]["Publisher"])

# %% [markdown]
# # Article Tuples

# %%
import datetime
from crossref.restful import Works

works = Works() # Initialize Works object

# Set the start date to January 1, 2025

articles = []
years = [2023, 2024, 2025]
query_limit = 1000

for publisher in publishers:
    for year in years:

        from_date = datetime.date(year, 1, 1)
        from_date_str = from_date.strftime('%Y-%m-%d')
        until_date_str = datetime.date.today().strftime('%Y-%m-%d')
        print(f"Searching for articles published by {publisher} from {year}. (limit {query_limit} per query)...")
        publisher_articles = []
        article_iterator = works.query(
            publisher_name=publisher
        ).filter(
            from_pub_date=from_date_str,
            until_pub_date=until_date_str
        )

        for article in article_iterator:
            publisher_articles.append(article)
            if len(publisher_articles) >= query_limit: # Manually enforce the limit per publisher
                break

        articles.extend(publisher_articles) # Add collected articles to the main list
# Out:
# Searching for articles published by WILEY from 2023. (limit 1000 per query)...
# Searching for articles published by WILEY from 2024. (limit 1000 per query)...
# Searching for articles published by WILEY from 2025. (limit 1000 per query)...
# Searching for articles published by ELSEVIER SCIENCE INC from 2023. (limit 1000 per query)...
# Searching for articles published by ELSEVIER SCIENCE INC from 2024. (limit 1000 per query)...
# Searching for articles published by ELSEVIER SCIENCE INC from 2025. (limit 1000 per query)...
# Searching for articles published by NATURE PORTFOLIO from 2023. (limit 1000 per query)...
# Searching for articles published by NATURE PORTFOLIO from 2024. (limit 1000 per query)...
# Searching for articles published by NATURE PORTFOLIO from 2025. (limit 1000 per query)...

# %%
articles_tuples = []
breaking = 0
for article in articles:
    # Skip cases where there is no article title
    title = article.get('title', None)
    if title is None:
        continue

    # Extract authors
    # Skip articles with no authors listed
    authors = article.get('author', [])
    author_names = []
    if authors:
        for author in authors:
            given_name = author.get('given', '')
            family_name = author.get('family', '')
            if given_name or family_name:
                author_names.append(f"{given_name} {family_name}".strip())
    else:
        continue

    author_number = 1
    for author in author_names:
        current_article = []

        # FIX: use the full title, not title[0]
        current_article.append(article.get('title', 'No Title Provided'))

        current_article.append(author)
        current_article.append(author_number)
        author_number += 1

        current_article.append(article.get('DOI', None))
        current_article.append(article.get('publisher', None))

        # FIX: round score to match DECIMAL(5,1)
        score = article.get('score', None)
        if score is not None:
            try:
                score = round(float(score), 1)
            except:
                score = None
        current_article.append(score)

        current_article.append(article.get('URL', None))

        # Safely get 'published' and then 'date-parts'
        published_info = article.get('published', None)
        if published_info != None:
            try:
                current_article.append(str(published_info['date-parts'][0][0]))  # year
            except:
                current_article.append(None)
        else:
            current_article.append(None)

        ISSN = article.get('ISSN', None)
        if ISSN != None:
            current_article.append(ISSN[0])
        else:
            current_article.append(None)
        journal=article.get('container-title', None)
        if journal != None:
            current_article.append(journal[0])
        ref_count = article.get("reference-count", None)
        if ref_count is None:
            ref_count = article.get("references-count", None)

        current_article.append(ref_count)
        current_article.append(article.get('is-referenced-by-count', None))

        articles_tuples.append(tuple(current_article))

# %%
articles[1]
# Out:
# {'indexed': {'date-parts': [[2025, 3, 14]],
#   'date-time': '2025-03-14T04:29:29Z',
#   'timestamp': 1741926569921,
#   'version': '3.38.0'},
#  'reference-count': 23,
#  'publisher': 'Wiley',
#  'issue': '185',
#  'license': [{'start': {'date-parts': [[2025, 2, 24]],
#     'date-time': '2025-02-24T00:00:00Z',
#     'timestamp': 1740355200000},
#    'content-version': 'vor',
#    'delay-in-days': 0,
#    'URL': 'http://creativecommons.org/licenses/by-nc/4.0/'}],
#  'content-domain': {'domain': ['onlinelibrary.wiley.com'],
#   'crossmark-restriction': True},
#  'short-container-title': ['New Drctns Student Lead'],
#  'published-print': {'date-parts': [[2025, 3]]},
#  'abstract': '<jats:title>ABSTRACT</jats:title><jats:p>This article applies the critical media concept of organic representation to leadership studies as an analytic of how various creators in popular culture today are not just writing inclusive storytelling but, more notably, modeling new modes of production and self‐presentation that are actively challenging hegemonic industry practices and larger cultural ideologies around power, equity, leadership, and success. In conversation with leadership for liberation (see Patterson‐Stephens et\xa0al. in this issue), I employ an interdisciplinary approach that bridges critical leadership models with critical media analysis to place their aligned perspectives in direct conversation with one another. In pursuant of adding critical media analysis to the leadership studies toolkit, this article applies organic representation to an original analysis of the television series <jats:italic>Reservation Dogs</jats:italic> and advocates for a critical interrogation of media storytelling, production, and distribution to better understand represented communities also as stakeholders in pop culture narratives.</jats:p>',
#  'DOI': '10.1002/yd.20660',
#  'type': 'journal-article',
#  'created': {'date-parts': [[2025, 2, 26]],
#   'date-time': '2025-02-26T09:06:47Z',
#   'timestamp': 1740560807000},
#  'page': '75-80',
#  'update-policy': 'https://doi.org/10.1002/crossmark_policy',
#  'source': 'Crossref',
#  'is-referenced-by-count': 1,
#  'title': ['Organic Representation as a Critical Media Approach to Leadership Studies in Popular Culture'],
#  'prefix': '10.1002',
#  'volume': '2025',
#  'author': [{'ORCID': 'https://orcid.org/0009-0003-0720-0320',
#    'authenticated-orcid': False,
#    'given': 'Raffi',
#    'family': 'Sarkissian',
#    'sequence': 'first',
#    'affiliation': [{'name': 'Department of Communication Christopher Newport University  Newport News Virginia USA'}]}],
#  'member': '311',
#  'published-online': {'date-parts': [[2025, 2, 24]]},
#  'reference': [{'key': 'e_1_2_6_2_1',
#    'unstructured': 'Boutsalis K.2021. “This Is What We Should Have Had All Along.”New York Times August 9.https://www.nytimes.com/2021/08/09/arts/television/reservation‐dogs‐rutherford‐falls.html.'},
#   {'key': 'e_1_2_6_3_1',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1080/10400419.2010.504654'},
#   {'key': 'e_1_2_6_4_1',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.18574/nyu/9781479814909.001.0001'},
#   {'key': 'e_1_2_6_5_1',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1353/cj.2020.0068'},
#   {'key': 'e_1_2_6_6_1',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1002/yd.20554'},
#   {'key': 'e_1_2_6_7_1',
#    'unstructured': 'Davis A.2018. “How STARZ Is Making History With Its Addictive New Show Vida.” Refinery29. May 4.https://www.refinery29.com/en‐us/2018/05/198202/vida‐starz‐historic‐latinx‐cast.'},
#   {'key': 'e_1_2_6_8_1',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1002/yd.20294'},
#   {'volume-title': 'Leadership Theory: Cultivating Critical Perspectives',
#    'year': '2024',
#    'author': 'Dugan J. P.',
#    'key': 'e_1_2_6_9_1'},
#   {'key': 'e_1_2_6_10_1',
#    'unstructured': 'Gross T.2022. “‘Reservation Dogs’ Co‐Creator Says the Show Gives Audiences Permission to Laugh.”NPR. September 19.https://www.npr.org/2022/09/19/1123452609/reservation‐dogs‐sterlin‐harjo‐native‐stories.'},
#   {'key': 'e_1_2_6_11_1',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.4324/9781003170310'},
#   {'key': 'e_1_2_6_12_1',
#    'unstructured': 'Lauzen M. M.2024. “Living Archive: The Celluloid Ceiling.”SDSU Center for the Study of Women in Television and Film.https://womenintvfilm.sdsu.edu/wp‐content/uploads/2024/07/2023‐living‐archive‐report.pdf.'},
#   {'key': 'e_1_2_6_13_1',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.4324/9781003007708'},
#   {'key': 'e_1_2_6_14_1',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1002/jls.21545'},
#   {'key': 'e_1_2_6_15_1',
#    'unstructured': 'OWN.2022. “OWN Spotlight: Oprah & Quinta Brunson [Television Special].”OWN. November 26.'},
#   {'issue': '185',
#    'key': 'e_1_2_6_16_1',
#    'article-title': 'Creating to Transgress: Supporting Student Leadership Development Through Culturally Informed Media Praxis',
#    'volume': '2025',
#    'author': 'Patterson‐Stephens S.',
#    'year': '2025',
#    'journal-title': 'New Directions for Student Leadership'},
#   {'key': 'e_1_2_6_17_1',
#    'unstructured': 'Ramón A. M.Tran andD.Hunt.2024. “Hollywood Diversity Report 2024.”UCLA Entertainment & Media Research Initiative.https://socialsciences.ucla.edu/wp‐content/uploads/2024/06/ucla‐hollywood‐diversity‐report‐2024‐film‐3‐7‐2024.pdf.'},
#   {'key': 'e_1_2_6_18_1',
#    'unstructured': "Rao S.2018. “‘Vida’ Crew Discusses TV's First All‐Latinx Writers Room.”Colorlines. May 4.https://colorlines.com/article/vida‐crew‐discusses‐tvs‐first‐all‐latinx‐writers‐room/."},
#   {'key': 'e_1_2_6_19_1',
#    'unstructured': 'Smith S. K.Peiper andS.Wheeler.2024. “Inequality in 1 700 Popular Films: Examining Portrayals of Gender Race/Ethnicity LGBTQ+ & Disability From 2007 to 2023.”USC Annenberg Inclusion Initiative.https://assets.uscannenberg.org/docs/aii‐popular‐films‐2024‐08‐02.pdf.'},
#   {'key': 'e_1_2_6_20_1',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1177/107780040200800103'},
#   {'key': 'e_1_2_6_21_1',
#    'unstructured': 'Variety.2024.Jennifer Aniston & Quinta Brunson l Actors on Actors [Video]. YouTube. June 6.https://www.youtube.com/watch?v=3iigcu2sr4i.'},
#   {'key': 'e_1_2_6_22_1',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1016/j.hrmr.2022.100894'},
#   {'key': 'e_1_2_6_23_1',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.4324/9781315779829'},
#   {'key': 'e_1_2_6_24_1',
#    'doi-asserted-by': 'publisher',
#    'DOI': '10.1525/fq.2017.71.2.32'}],
#  'container-title': ['New Directions for Student Leadership'],
#  'language': 'en',
#  'link': [{'URL': 'https://onlinelibrary.wiley.com/doi/pdf/10.1002/yd.20660',
#    'content-type': 'unspecified',
#    'content-version': 'vor',
#    'intended-application': 'similarity-checking'}],
#  'deposited': {'date-parts': [[2025, 3, 14]],
#   'date-time': '2025-03-14T02:26:09Z',
#   'timestamp': 1741919169000},
#  'score': 3.7475216,
#  'resource': {'primary': {'URL': 'https://onlinelibrary.wiley.com/doi/10.1002/yd.20660'}},
#  'issued': {'date-parts': [[2025, 2, 24]]},
#  'references-count': 23,
#  'journal-issue': {'issue': '185',
#   'published-print': {'date-parts': [[2025, 3]]}},
#  'alternative-id': ['10.1002/yd.20660'],
#  'URL': 'https://doi.org/10.1002/yd.20660',
#  'archive': ['Portico'],
#  'ISSN': ['2373-3349', '2373-3357'],
#  'issn-type': [{'type': 'print', 'value': '2373-3349'},
#   {'type': 'electronic', 'value': '2373-3357'}],
#  'published': {'date-parts': [[2025, 2, 24]]},
#  'assertion': [{'value': '2025-02-24',
#    'order': 3,
#    'name': 'published',
#    'label': 'Published',
#    'group': {'name': 'publication_history', 'label': 'Publication History'}}]}

# %%
with open("article_tuples.txt", "w", encoding="utf-8") as j:
    for article in articles_tuples:
        fixed = list(article)
        if isinstance(fixed[0], list):
            fixed[0] = fixed[0][0]

        cleaned = [
            normalize(v) if isinstance(v, str) else v
            for v in fixed
        ]

        values_sql = ", ".join(sql_literal(v) for v in cleaned)

        j.write(
            f"INSERT INTO Articles VALUES ({values_sql}) "
            f"ON CONFLICT (Title, Author_Number) DO NOTHING;\n"
        )

# %% [markdown]
# # ROR tuples

# %%
affiliation_list = set()
for article in articles:
    authors = article.get('author', [])
    if authors:
        for author in authors:
            affiliation = author.get('affiliation', "")
            if affiliation:
                for n in affiliation:
                    affiliation_list.add(n['name'])

# %%
import requests
institution_details = []
weird_format= []

for affiliation in affiliation_list:
    url = f"https://api.ror.org/organizations?query={affiliation}"
    response = requests.get(url)

    if response.status_code == 200:
        data = response.json()

        if 'items' in data and isinstance(data['items'], list) and len(data['items']) > 0:
            try:
                item = data['items'][0]
                name = item.get('name', affiliation) # Use affiliation as fallback for name
                established = item.get('established', None)

                country_code = None
                locations = item.get('locations')

                if locations and isinstance(locations, list) and len(locations) > 0:
                    first_location = locations[0]
                    geonames_details = first_location.get('geonames_details')
                    if geonames_details:
                        country_code = geonames_details.get('country_code', None)
                institution_details.append([name, established, country_code])

            except (IndexError, KeyError, TypeError) as e:
                weird_format.append(affiliation)
            except Exception as e:
                weird_format.append(affiliation)
        else:
            weird_format.append(affiliation)
    else:
        weird_format.append(affiliation)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 7
#       5 for affiliation in affiliation_list:
#       6     url = f"https://api.ror.org/organizations?query={affiliation}"
# ----> 7     response = requests.get(url)
#       9     if response.status_code == 200:
#      10         data = response.json()
#
# File /usr/local/lib/python3.12/dist-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File /usr/local/lib/python3.12/dist-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File /usr/local/lib/python3.12/dist-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File /usr/local/lib/python3.12/dist-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File /usr/local/lib/python3.12/dist-packages/requests/adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File /usr/local/lib/python3.12/dist-packages/urllib3/connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     784 response_conn = conn if not release_conn else None
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#     803 clean_exit = True
#
# File /usr/local/lib/python3.12/dist-packages/urllib3/connectionpool.py:534, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     532 # Receive the response from the server
#     533 try:
# --> 534     response = conn.getresponse()
#     535 except (BaseSSLError, OSError) as e:
#     536     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File /usr/local/lib/python3.12/dist-packages/urllib3/connection.py:565, in HTTPConnection.getresponse(self)
#     562 _shutdown = getattr(self.sock, "shutdown", None)
#     564 # Get the response from http.client.HTTPConnection
# --> 565 httplib_response = super().getresponse()
#     567 try:
#     568     assert_header_parsing(httplib_response.msg)
#
# File /usr/lib/python3.12/http/client.py:1430, in HTTPConnection.getresponse(self)
#    1428 try:
#    1429     try:
# -> 1430         response.begin()
#    1431     except ConnectionError:
#    1432         self.close()
#
# File /usr/lib/python3.12/http/client.py:331, in HTTPResponse.begin(self)
#     329 # read until we get a non-100 response
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#     333         break
#
# File /usr/lib/python3.12/http/client.py:292, in HTTPResponse._read_status(self)
#     291 def _read_status(self):
# --> 292     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     293     if len(line) > _MAXLINE:
#     294         raise LineTooLong("status line")
#
# File /usr/lib/python3.12/socket.py:720, in SocketIO.readinto(self, b)
#     718 while True:
#     719     try:
# --> 720         return self._sock.recv_into(b)
#     721     except timeout:
#     722         self._timeout_occurred = True
#
# File /usr/lib/python3.12/ssl.py:1251, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1247     if flags != 0:
#    1248         raise ValueError(
#    1249           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1250           self.__class__)
# -> 1251     return self.read(nbytes, buffer)
#    1252 else:
#    1253     return super().recv_into(buffer, nbytes, flags)
#
# File /usr/lib/python3.12/ssl.py:1103, in SSLSocket.read(self, len, buffer)
#    1101 try:
#    1102     if buffer is not None:
# -> 1103         return self._sslobj.read(len, buffer)
#    1104     else:
#    1105         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
institution_details[0]
# Out:
# ['Institute of Communications and Navigation German Aerospace Center (DLR e.V.)  Wessling Germany',
#  1969,
#  'DE']

# %%
with open("institution_tuples.txt", "w") as j:
    for institution in institution_details:
        values_sql = ", ".join(sql_literal(v) for v in institution)
        j.write(
            f"INSERT INTO Institutions VALUES ({values_sql}) "
            "ON CONFLICT (Name) DO NOTHING;\n"
        )

# %% [markdown]
# # Authors

# %%
from google.colab import userdata
ORCID_client_id=userdata.get("ORCID_client_id")
ORCID_client_secret=userdata.get("ORCID_client_secret")

# %%
import orcid

client = orcid.PublicAPI(ORCID_client_id, ORCID_client_secret)
consecutive_api_failures = 0
authors_processed = {}
author_orcids_found = {}

print("ORCID API client initialized and variables set.")
# Out:
# ORCID API client initialized and variables set.

# %%
unique_authors = {}

for article in articles:
    authors = article.get('author', [])
    if not authors:
        continue

    for author in authors:
        given_name = author.get('given', '')
        family_name = author.get('family', '')

        # Construct full_name for easier identification, though key is (family, given)
        full_name = f"{given_name} {family_name}".strip()

        # Extract affiliation names
        affiliations = author.get('affiliation', [])
        affiliation_names = set()
        if affiliations:
            for aff_item in affiliations:
                if 'name' in aff_item:
                    affiliation_names.add(aff_item['name'])
        else:
            # If no specific affiliations are provided, use a placeholder
            affiliation_names.add('No Affiliation Provided')

        author_key = (family_name, given_name) # Using a tuple as key for uniqueness

        if author_key not in unique_authors:
            unique_authors[author_key] = set()
        unique_authors[author_key].update(affiliation_names)

print(f"Processed {len(articles)} articles. Found {len(unique_authors)} unique authors with affiliations.")
# Out:
# Processed 9000 articles. Found 18128 unique authors with affiliations.

# %%
author_queries = {}

for (family_name, given_name), affiliations in unique_authors.items():
    queries = []

    primary_affiliation = 'No Affiliation Provided'
    if affiliations and 'No Affiliation Provided' not in affiliations: # Prioritize actual affiliations over placeholder
        primary_affiliation = list(affiliations)[0]

    # Query 1: Full name and primary affiliation (if available and not placeholder)
    if given_name and family_name and primary_affiliation != 'No Affiliation Provided':
        queries.append(f"family-name:{family_name} AND given-names:{given_name} AND affiliation-org-name:\"{primary_affiliation}\"")

    # Query 2: Full name only
    if given_name and family_name:
        queries.append(f"family-name:{family_name} AND given-names:{given_name}")

    # Query 3: Family name only (if given name is empty or affiliation not used)
    if family_name and not given_name and not queries: # Only add if no other query was possible yet with the family name
        queries.append(f"family-name:{family_name}")
    elif family_name and given_name and not queries[0].startswith(f"family-name:{family_name} AND given-names:{given_name}"): # If full name query exists, skip family-name only
        queries.append(f"family-name:{family_name}")

    # Query 4: Given name only (as a last resort if family name is also missing)
    if given_name and not family_name and not queries:
        queries.append(f"given-names:{given_name}")

    author_queries[(family_name, given_name)] = queries

# %%
orcid_tuples = []
MAX_CONSECUTIVE_API_FAILURES = 10

try:
    public_access_token = client.get_search_token_from_orcid()
    print("Successfully obtained public access token for ORCID API.")
except Exception as e:
    print(f"Error obtaining public access token: {e}")
    public_access_token = None # Ensure it's None if acquisition fails

if public_access_token is None:
    print("Cannot proceed with ORCID searches without a public access token.")
else:
    consecutive_api_failures = 0
    author_orcids_found = {}

    for author_key, queries in author_queries.items():
        if author_key in author_orcids_found:
            continue # Skip if ORCID already found for this author

        found_orcid_id = None
        current_primary_affiliation = list(unique_authors[author_key])[0] if unique_authors[author_key] else 'No Affiliation Provided'

        for query in queries:
            if consecutive_api_failures >= MAX_CONSECUTIVE_API_FAILURES:
                print(f"Stopping ORCID search due to {MAX_CONSECUTIVE_API_FAILURES} consecutive API failures.")
                break # Break inner loop

            try:
                search_response = client.search(query, access_token=public_access_token)

                if search_response and 'result' in search_response:
                    consecutive_api_failures = 0 # Reset failure counter on success
                    search_results = search_response['result']

                    if search_results:
                        best_match_orcid = None
                        # Prioritize by affiliation if available and not 'No Affiliation Provided'
                        if current_primary_affiliation != 'No Affiliation Provided':
                            for result in search_results:
                                # Simplified approach: if a query with affiliation yielded results, and there's a single result, take it.
                                # This logic is based on the assumption that if an affiliation was used in the query, and it returned a single result,
                                # that result is the most relevant. If multiple results or a broader query, take the first.
                                if 'affiliation-org-name' in query and len(search_results) == 1:
                                    best_match_orcid = result['orcid-identifier']['path']
                                    break # Found a highly specific match

                            if best_match_orcid is None: # If no single specific match by affiliation query, take first
                                best_match_orcid = search_results[0]['orcid-identifier']['path']
                        else: # No primary affiliation to match, just take the first result
                            best_match_orcid = search_results[0]['orcid-identifier']['path']

                        found_orcid_id = best_match_orcid
                        break # ORCID found, break from inner query loop
                else:
                    # Search response was empty or did not contain 'result'
                    consecutive_api_failures += 1

            except Exception as e:
                consecutive_api_failures += 1
                print(f"Warning: ORCID API call failed for query '{query}': {e}. Consecutive failures: {consecutive_api_failures}")
                if consecutive_api_failures >= MAX_CONSECUTIVE_API_FAILURES:
                    break # Break inner loop if too many failures

        if found_orcid_id:
            author_orcids_found[author_key] = found_orcid_id
            family_name_str, given_name_str = author_key
            author_display_name = f"{given_name_str} {family_name_str}".strip()
            orcid_tuples.append((author_display_name, current_primary_affiliation, found_orcid_id))
        else:
            family_name_str, given_name_str = author_key
            author_display_name = f"{given_name_str} {family_name_str}".strip()

        if consecutive_api_failures >= MAX_CONSECUTIVE_API_FAILURES:
            break # Break outer loop as well

print(f"Found {len(orcid_tuples)} ORCID records.")
print(f"Example ORCID tuples: {orcid_tuples[:5]}")
# Out:
# Successfully obtained public access token for ORCID API.
# Warning: ORCID API call failed for query 'family-name:Huang AND given-names:Xuan AND affiliation-org-name:"Department of Pharmacy Obstetrics &amp; Gynecology Hospital of Fudan University  Shanghai China"': 500 Server Error:  for url: https://pub.orcid.org/v2.0/search/?defType=lucene&q=family-name:Huang%20AND%20given-names:Xuan%20AND%20affiliation-org-name:%22Department%20of%20Pharmacy%20Obstetrics%20&amp;%20Gynecology%20Hospital%20of%20Fudan%20University%20%20Shanghai%20China%22. Consecutive failures: 1
# Warning: ORCID API call failed for query 'family-name:Li AND given-names:Junmin AND affiliation-org-name:"Department of Pharmacy Obstetrics &amp; Gynecology Hospital of Fudan University  Shanghai China"': 500 Server Error:  for url: https://pub.orcid.org/v2.0/search/?defType=lucene&q=family-name:Li%20AND%20given-names:Junmin%20AND%20affiliation-org-name:%22Department%20of%20Pharmacy%20Obstetrics%20&amp;%20Gynecology%20Hospital%20of%20Fudan%20University%20%20Shanghai%20China%22. Consecutive failures: 1
# Warning: ORCID API call failed for query 'family-name:Pang AND given-names:Xiaoying AND affiliation-org-name:"Department of Pharmacy Obstetrics &amp; Gynecology Hospital of Fudan University  Shanghai China"': 500 Server Error:  for url: https://pub.orcid.org/v2.0/search/?defType=lucene&q=family-name:Pang%20AND%20given-names:Xiaoying%20AND%20affiliation-org-name:%22Department%20of%20Pharmacy%20Obstetrics%20&amp;%20Gynecology%20Hospital%20of%20Fudan%20University%20%20Shanghai%20China%22. Consecutive failures: 1
# Warning: ORCID API call failed for query 'family-name:Zhu AND given-names:Jialei AND affiliation-org-name:"Department of Pharmacy Obstetrics &amp; Gynecology Hospital of Fudan University  Shanghai China"': 500 Server Error:  for url: https://pub.orcid.org/v2.0/search/?defType=lucene&q=family-name:Zhu%20AND%20given-names:Jialei%20AND%20affiliation-org-name:%22Department%20of%20Pharmacy%20Obstetrics%20&amp;%20Gynecology%20Hospital%20of%20Fudan%20University%20%20Shanghai%20China%22. Consecutive failures: 1
# Warning: ORCID API call failed for query 'family-name:Pan AND given-names:Jiaqian AND affiliation-org-name:"Department of Pharmacy Obstetrics &amp; Gynecology Hospital of Fudan University  Shanghai China"': 500 Server Error:  for url: https://pub.orcid.org/v2.0/search/?defType=lucene&q=family-name:Pan%20AND%20given-names:Jiaqian%20AND%20affiliation-org-name:%22Department%20of%20Pharmacy%20Obstetrics%20&amp;%20Gynecology%20Hospital%20of%20Fudan%20University%20%20Shanghai%20China%22. Consecutive failures: 1
# Warning: ORCID API call failed for query 'family-name:Li AND given-names:Yueyan AND affiliation-org-name:"Department of Pharmacy Obstetrics &amp; Gynecology Hospital of Fudan University  Shanghai China"': 500 Server Error:  for url: https://pub.orcid.org/v2.0/search/?defType=lucene&q=family-name:Li%20AND%20given-names:Yueyan%20AND%20affiliation-org-name:%22Department%20of%20Pharmacy%20Obstetrics%20&amp;%20Gynecology%20Hospital%20of%20Fudan%20University%20%20Shanghai%20China%22. Consecutive failures: 1
# Warning: ORCID API call failed for query 'family-name:Tang AND given-names:Jing AND affiliation-org-name:"Department of Pharmacy Obstetrics &amp; Gynecology Hospital of Fudan University  Shanghai China"': 500 Server Error:  for url: https://pub.orcid.org/v2.0/search/?defType=lucene&q=family-name:Tang%20AND%20given-names:Jing%20AND%20affiliation-org-name:%22Department%20of%20Pharmacy%20Obstetrics%20&amp;%20Gynecology%20Hospital%20of%20Fudan%20University%20%20Shanghai%20China%22. Consecutive failures: 1
# Warning: ORCID API call failed for query 'family-name:Wei AND given-names:Jiamin AND affiliation-org-name:"School of Communication &amp; Information Engineering Shanghai University  Shanghai China"': 500 Server Error:  for url: https://pub.orcid.org/v2.0/search/?defType=lucene&q=family-name:Wei%20AND%20given-names:Jiamin%20AND%20affiliation-org-name:%22School%20of%20Communication%20&amp;%20Information%20Engineering%20Shanghai%20University%20%20Shanghai%20China%22. Consecutive failures: 1
# Warning: ORCID API call failed for query 'family-name:Yang AND given-names:Xue‐Xia AND affiliation-org-name:"School of Communication &amp; Information Engineering Shanghai University  Shanghai China"': 500 Server Error:  for url: https://pub.orcid.org/v2.0/search/?defType=lucene&q=family-name:Yang%20AND%20given-names:Xue%E2%80%90Xia%20AND%20affiliation-org-name:%22School%20of%20Communication%20&amp;%20Information%20Engineering%20Shanghai%20University%20%20Shanghai%20China%22. Consecutive failures: 1
# Warning: ORCID API call failed for query 'family-name:Lou AND given-names:Tian AND affiliation-org-name:"School of Communication &amp; Information Engineering Shanghai University  Shanghai China"': 500 Server Error:  for url: https://pub.orcid.org/v2.0/search/?defType=lucene&q=family-name:Lou%20AND%20given-names:Tian%20AND%20affiliation-org-name:%22School%20of%20Communication%20&amp;%20Information%20Engineering%20Shanghai%20University%20%20Shanghai%20China%22. Consecutive failures: 1
# Warning: ORCID API call failed for query 'family-name:Cao AND given-names:Qi‐Dong AND affiliation-org-name:"School of Communication &amp; Information Engineering Shanghai University  Shanghai China"': 500 Server Error:  for url: https://pub.orcid.org/v2.0/search/?defType=lucene&q=family-name:Cao%20AND%20given-names:Qi%E2%80%90Dong%20AND%20affiliation-org-name:%22School%20of%20Communication%20&amp;%20Information%20Engineering%20Shanghai%20University%20%20Shanghai%20China%22. Consecutive failures: 1
# Warning: ORCID API call failed for query 'family-name:Yamamoto-Mitani AND given-names:Noriko AND affiliation-org-name:"Department of Gerontological Home-Care & Long-Term Care Nursing, Graduate School of Medicine, The University of Tokyo, Tokyo, Japan"': 500 Server Error:  for url: https://pub.orcid.org/v2.0/search/?defType=lucene&q=family-name:Yamamoto-Mitani%20AND%20given-names:Noriko%20AND%20affiliation-org-name:%22Department%20of%20Gerontological%20Home-Care%20&%20Long-Term%20Care%20Nursing,%20Graduate%20School%20of%20Medicine,%20The%20University%20of%20Tokyo,%20Tokyo,%20Japan%22. Consecutive failures: 1
# Warning: ORCID API call failed for query 'family-name:Han AND given-names:Yongliang AND affiliation-org-name:"China Coal Technology & Engineering Group Xi’an Research Institute, Xi’an, Shanxi 710077, China"': 500 Server Error:  for url: https://pub.orcid.org/v2.0/search/?defType=lucene&q=family-name:Han%20AND%20given-names:Yongliang%20AND%20affiliation-org-name:%22China%20Coal%20Technology%20&%20Engineering%20Group%20Xi%E2%80%99an%20Research%20Institute,%20Xi%E2%80%99an,%20Shanxi%20710077,%20China%22. Consecutive failures: 1
# Warning: ORCID API call failed for query 'family-name:VALVERDE AND given-names:MARIANA AND affiliation-org-name:"Centre for Criminology &amp; Sociolegal Studies University of Toronto  Toronto Canada"': 500 Server Error:  for url: https://pub.orcid.org/v2.0/search/?defType=lucene&q=family-name:VALVERDE%20AND%20given-names:MARIANA%20AND%20affiliation-org-name:%22Centre%20for%20Criminology%20&amp;%20Sociolegal%20Studies%20University%20of%20Toronto%20%20Toronto%20Canada%22. Consecutive failures: 1
# Warning: ORCID API call failed for query 'family-name:Chandra AND given-names:Avinash AND affiliation-org-name:"Thapar Institute of Engineering &amp; Technology Department of Chemical Engineering  147004 Patiala India"': 500 Server Error:  for url: https://pub.orcid.org/v2.0/search/?defType=lucene&q=family-name:Chandra%20AND%20given-names:Avinash%20AND%20affiliation-org-name:%22Thapar%20Institute%20of%20Engineering%20&amp;%20Technology%20Department%20of%20Chemical%20Engineering%20%20147004%20Patiala%20India%22. Consecutive failures: 1
# Warning: ORCID API call failed for query 'family-name:Singh AND given-names:Sukh Veer AND affiliation-org-name:"Department of Food Technology and Management, Loyola Academy (Degree & PG College), Old Alwal, Secunderabad, Telangana 500010, India"': 500 Server Error:  for url: https://pub.orcid.org/v2.0/search/?defType=lucene&q=family-name:Singh%20AND%20given-names:Sukh%20Veer%20AND%20affiliation-org-name:%22Department%20of%20Food%20Technology%20and%20Management,%20Loyola%20Academy%20(Degree%20&%20PG%20College),%20Old%20Alwal,%20Secunderabad,%20Telangana%20500010,%20India%22. Consecutive failures: 1
# Warning: ORCID API call failed for query 'family-name:Obergassel AND given-names:J. AND affiliation-org-name:"Department of Cardiology University Heart &amp; Vascular Center Hamburg, University Medical Center Hamburg‐Eppendorf Hamburg Germany"': 500 Server Error:  for url: https://pub.orcid.org/v2.0/search/?defType=lucene&q=family-name:Obergassel%20AND%20given-names:J.%20AND%20affiliation-org-name:%22Department%20of%20Cardiology%20University%20Heart%20&amp;%20Vascular%20Center%20Hamburg,%20University%20Medical%20Center%20Hamburg%E2%80%90Eppendorf%20Hamburg%20Germany%22. Consecutive failures: 1
# Warning: ORCID API call failed for query 'family-name:Nies AND given-names:M. AND affiliation-org-name:"Department of Cardiology University Heart &amp; Vascular Center Hamburg, University Medical Center Hamburg‐Eppendorf Hamburg Germany"': 500 Server Error:  for url: https://pub.orcid.org/v2.0/search/?defType=lucene&q=family-name:Nies%20AND%20given-names:M.%20AND%20affiliation-org-name:%22Department%20of%20Cardiology%20University%20Heart%20&amp;%20Vascular%20Center%20Hamburg,%20University%20Medical%20Center%20Hamburg%E2%80%90Eppendorf%20Hamburg%20Germany%22. Consecutive failures: 1
# Warning: ORCID API call failed for query 'family-name:Metzner AND given-names:A. AND affiliation-org-name:"Department of Cardiology University Heart &amp; Vascular Center Hamburg, University Medical Center Hamburg‐Eppendorf Hamburg Germany"': 500 Server Error:  for url: https://pub.orcid.org/v2.0/search/?defType=lucene&q=family-name:Metzner%20AND%20given-names:A.%20AND%20affiliation-org-name:%22Department%20of%20Cardiology%20University%20Heart%20&amp;%20Vascular%20Center%20Hamburg,%20University%20Medical%20Center%20Hamburg%E2%80%90Eppendorf%20Hamburg%20Germany%22. Consecutive failures: 1
# Warning: ORCID API call failed for query 'family-name:Bälz AND given-names:Uwe AND affiliation-org-name:"W. Baelz &amp; Sohn GmbH &amp; Co., Heilbronn"': 500 Server Error:  for url: https://pub.orcid.org/v2.0/search/?defType=lucene&q=family-name:B%C3%A4lz%20AND%20given-names:Uwe%20AND%20affiliation-org-name:%22W.%20Baelz%20&amp;%20Sohn%20GmbH%20&amp;%20Co.,%20Heilbronn%22. Consecutive failures: 1
# Warning: ORCID API call failed for query 'family-name:Wäsche AND given-names:Timo AND affiliation-org-name:"W. Baelz &amp; Sohn GmbH &amp; Co., Heilbronn"': 500 Server Error:  for url: https://pub.orcid.org/v2.0/search/?defType=lucene&q=family-name:W%C3%A4sche%20AND%20given-names:Timo%20AND%20affiliation-org-name:%22W.%20Baelz%20&amp;%20Sohn%20GmbH%20&amp;%20Co.,%20Heilbronn%22. Consecutive failures: 1
# Warning: ORCID API call failed for query 'family-name:Goh AND given-names:Guan Lin AND affiliation-org-name:"Department of Neonatology KK Women's &amp; Children's Hospital  Singapore City Singapore"': 500 Server Error:  for url: https://pub.orcid.org/v2.0/search/?defType=lucene&q=family-name:Goh%20AND%20given-names:Guan%20Lin%20AND%20affiliation-org-name:%22Department%20of%20Neonatology%20KK%20Women's%20&amp;%20Children's%20Hospital%20%20Singapore%20City%20Singapore%22. Consecutive failures: 1
# Warning: ORCID API call failed for query 'family-name:Betz AND given-names:Regina C. AND affiliation-org-name:"Institute of Human Genetics University of Bonn, Medical Faculty &amp; University Hospital Bonn  Bonn Germany"': 500 Server Error:  for url: https://pub.orcid.org/v2.0/search/?defType=lucene&q=family-name:Betz%20AND%20given-names:Regina%20C.%20AND%20affiliation-org-name:%22Institute%20of%20Human%20Genetics%20University%20of%20Bonn,%20Medical%20Faculty%20&amp;%20University%20Hospital%20Bonn%20%20Bonn%20Germany%22. Consecutive failures: 1
# Warning: ORCID API call failed for query 'family-name:Callender AND given-names:Valerie AND affiliation-org-name:"Callender Dermatology &amp; Cosmetic Center  Glenn Dale Maryland USA"': 500 Server Error:  for url: https://pub.orcid.org/v2.0/search/?defType=lucene&q=family-name:Callender%20AND%20given-names:Valerie%20AND%20affiliation-org-name:%22Callender%20Dermatology%20&amp;%20Cosmetic%20Center%20%20Glenn%20Dale%20Maryland%20USA%22. Consecutive failures: 1
# Warning: ORCID API call failed for query 'family-name:Dhurat AND given-names:Rachita AND affiliation-org-name:"Department of Dermatology LTM Medical College &amp; Hospital Sion  Mumbai India"': 500 Server Error:  for url: https://pub.orcid.org/v2.0/search/?defType=lucene&q=family-name:Dhurat%20AND%20given-names:Rachita%20AND%20affiliation-org-name:%22Department%20of%20Dermatology%20LTM%20Medical%20College%20&amp;%20Hospital%20Sion%20%20Mumbai%20India%22. Consecutive failures: 1
# Warning: ORCID API call failed for query 'family-name:Gadzhigoroeva AND given-names:Aida AND affiliation-org-name:"Scientific &amp; Practical Center Dermatolovenereology and Cosmetology of the Moscow City Health Department  Moscow Russian Federation"': 500 Server Error:  for url: https://pub.orcid.org/v2.0/search/?defType=lucene&q=family-name:Gadzhigoroeva%20AND%20given-names:Aida%20AND%20affiliation-org-name:%22Scientific%20&amp;%20Practical%20Center%20Dermatolovenereology%20and%20Cosmetology%20of%20the%20Moscow%20City%20Health%20Department%20%20Moscow%20Russian%20Federation%22. Consecutive failures: 1
# Warning: ORCID API call failed for query 'family-name:Harries AND given-names:Matthew AND affiliation-org-name:"Centre for Dermatology Research, Faculty of Biology, Medicine and Health University of Manchester &amp; NIHR Biomedical Research Centre  Manchester UK"': 500 Server Error:  for url: https://pub.orcid.org/v2.0/search/?defType=lucene&q=family-name:Harries%20AND%20given-names:Matthew%20AND%20affiliation-org-name:%22Centre%20for%20Dermatology%20Research,%20Faculty%20of%20Biology,%20Medicine%20and%20Health%20University%20of%20Manchester%20&amp;%20NIHR%20Biomedical%20Research%20Centre%20%20Manchester%20UK%22. Consecutive failures: 1
# Warning: ORCID API call failed for query 'family-name:Vañó‐Galván AND given-names:Sergio AND affiliation-org-name:"Director of Hair Disorders Unit and #TricoHRC Research Group  Madrid Spain"': 500 Server Error:  for url: https://pub.orcid.org/v2.0/search/?defType=lucene&q=family-name:Va%C3%B1%C3%B3%E2%80%90Galv%C3%A1n%20AND%20given-names:Sergio%20AND%20affiliation-org-name:%22Director%20of%20Hair%20Disorders%20Unit%20and%20#TricoHRC%20Research%20Group%20%20Madrid%20Spain%22. Consecutive failures: 1
# Warning: ORCID API call failed for query 'family-name:Puranik AND given-names:Cynthia AND affiliation-org-name:"Department of Communication Science &amp; Disorders Georgia State University  Atlanta Georgia USA"': 500 Server Error:  for url: https://pub.orcid.org/v2.0/search/?defType=lucene&q=family-name:Puranik%20AND%20given-names:Cynthia%20AND%20affiliation-org-name:%22Department%20of%20Communication%20Science%20&amp;%20Disorders%20Georgia%20State%20University%20%20Atlanta%20Georgia%20USA%22. Consecutive failures: 1
# Warning: ORCID API call failed for query 'family-name:Yadav AND given-names:Seema AND affiliation-org-name:"Department of Periodontology &amp; Oral Implantology Faculty of Dentistry, SEGi University, Kota Damansara  Petaling Jaya, Selangor Malaysia"': 500 Server Error:  for url: https://pub.orcid.org/v2.0/search/?defType=lucene&q=family-name:Yadav%20AND%20given-names:Seema%20AND%20affiliation-org-name:%22Department%20of%20Periodontology%20&amp;%20Oral%20Implantology%20Faculty%20of%20Dentistry,%20SEGi%20University,%20Kota%20Damansara%20%20Petaling%20Jaya,%20Selangor%20Malaysia%22. Consecutive failures: 1
# Warning: ORCID API call failed for query 'family-name:Ghani AND given-names:Wan Maria Nabillah AND affiliation-org-name:"Department of Oral Cancer Research &amp; Coordinating Centre (OCRCC) Faculty of Dentistry, University of Malaya  Kuala Lumpur Malaysia"': 500 Server Error:  for url: https://pub.orcid.org/v2.0/search/?defType=lucene&q=family-name:Ghani%20AND%20given-names:Wan%20Maria%20Nabillah%20AND%20affiliation-org-name:%22Department%20of%20Oral%20Cancer%20Research%20&amp;%20Coordinating%20Centre%20(OCRCC)%20Faculty%20of%20Dentistry,%20University%20of%20Malaya%20%20Kuala%20Lumpur%20Malaysia%22. Consecutive failures: 1
# Warning: ORCID API call failed for query 'family-name:Jenerson AND given-names:E. Simone AND affiliation-org-name:"Head of Product Accessibility &amp; Inclusion at Aon  Belleville New Jersey USA"': 500 Server Error:  for url: https://pub.orcid.org/v2.0/search/?defType=lucene&q=family-name:Jenerson%20AND%20given-names:E.%20Simone%20AND%20affiliation-org-name:%22Head%20of%20Product%20Accessibility%20&amp;%20Inclusion%20at%20Aon%20%20Belleville%20New%20Jersey%20USA%22. Consecutive failures: 1
# Warning: ORCID API call failed for query 'family-name:Kuchavaram AND given-names:Madhukar AND affiliation-org-name:"Department of Computer Science, College of Engineering and Computer Science Texas A&amp;M University ‐ Corpus Christi  Corpus Christi Texas USA"': 500 Server Error:  for url: https://pub.orcid.org/v2.0/search/?defType=lucene&q=family-name:Kuchavaram%20AND%20given-names:Madhukar%20AND%20affiliation-org-name:%22Department%20of%20Computer%20Science,%20College%20of%20Engineering%20and%20Computer%20Science%20Texas%20A&amp;M%20University%20%E2%80%90%20Corpus%20Christi%20%20Corpus%20Christi%20Texas%20USA%22. Consecutive failures: 1
# Warning: ORCID API call failed for query 'family-name:Huang AND given-names:Yuxia AND affiliation-org-name:"Department of Computer Science, College of Engineering and Computer Science Texas A&amp;M University ‐ Corpus Christi  Corpus Christi Texas USA"': 500 Server Error:  for url: https://pub.orcid.org/v2.0/search/?defType=lucene&q=family-name:Huang%20AND%20given-names:Yuxia%20AND%20affiliation-org-name:%22Department%20of%20Computer%20Science,%20College%20of%20Engineering%20and%20Computer%20Science%20Texas%20A&amp;M%20University%20%E2%80%90%20Corpus%20Christi%20%20Corpus%20Christi%20Texas%20USA%22. Consecutive failures: 1
# Warning: ORCID API call failed for query 'family-name:Murray AND given-names:Kate AND affiliation-org-name:"Faculty of Health, School of Psychology &amp; Counselling, Queensland University of Technology (QUT)  Brisbane Queensland Australia"': 500 Server Error:  for url: https://pub.orcid.org/v2.0/search/?defType=lucene&q=family-name:Murray%20AND%20given-names:Kate%20AND%20affiliation-org-name:%22Faculty%20of%20Health,%20School%20of%20Psychology%20&amp;%20Counselling,%20Queensland%20University%20of%20Technology%20(QUT)%20%20Brisbane%20Queensland%20Australia%22. Consecutive failures: 1
# Warning: ORCID API call failed for query 'family-name:Shochet AND given-names:Ian AND affiliation-org-name:"Faculty of Health, School of Psychology &amp; Counselling, Queensland University of Technology (QUT)  Brisbane Queensland Australia"': 500 Server Error:  for url: https://pub.orcid.org/v2.0/search/?defType=lucene&q=family-name:Shochet%20AND%20given-names:Ian%20AND%20affiliation-org-name:%22Faculty%20of%20Health,%20School%20of%20Psychology%20&amp;%20Counselling,%20Queensland%20University%20of%20Technology%20(QUT)%20%20Brisbane%20Queensland%20Australia%22. Consecutive failures: 1
# Warning: ORCID API call failed for query 'family-name:Sampoornam Pape Reddy AND given-names:Saravanan AND affiliation-org-name:"Department of Periodontology Army Dental Centre (Research &amp; Referral)  New Delhi India"': 500 Server Error:  for url: https://pub.orcid.org/v2.0/search/?defType=lucene&q=family-name:Sampoornam%20Pape%20Reddy%20AND%20given-names:Saravanan%20AND%20affiliation-org-name:%22Department%20of%20Periodontology%20Army%20Dental%20Centre%20(Research%20&amp;%20Referral)%20%20New%20Delhi%20India%22. Consecutive failures: 1
# Warning: ORCID API call failed for query 'family-name:Rathi AND given-names:Manish AND affiliation-org-name:"Department of Periodontology Army Dental Centre (Research &amp; Referral)  New Delhi India"': 500 Server Error:  for url: https://pub.orcid.org/v2.0/search/?defType=lucene&q=family-name:Rathi%20AND%20given-names:Manish%20AND%20affiliation-org-name:%22Department%20of%20Periodontology%20Army%20Dental%20Centre%20(Research%20&amp;%20Referral)%20%20New%20Delhi%20India%22. Consecutive failures: 1
# Warning: ORCID API call failed for query 'family-name:Harish AND given-names:Ruchi AND affiliation-org-name:"Department of Periodontology Army Dental Centre (Research &amp; Referral)  New Delhi India"': 500 Server Error:  for url: https://pub.orcid.org/v2.0/search/?defType=lucene&q=family-name:Harish%20AND%20given-names:Ruchi%20AND%20affiliation-org-name:%22Department%20of%20Periodontology%20Army%20Dental%20Centre%20(Research%20&amp;%20Referral)%20%20New%20Delhi%20India%22. Consecutive failures: 1
# Warning: ORCID API call failed for query 'family-name:Pradhan AND given-names:Shaili AND affiliation-org-name:"Department of Periodontology &amp; Oral Implantology Kathmandu Medical College Public Limited  Kathmandu Nepal"': 500 Server Error:  for url: https://pub.orcid.org/v2.0/search/?defType=lucene&q=family-name:Pradhan%20AND%20given-names:Shaili%20AND%20affiliation-org-name:%22Department%20of%20Periodontology%20&amp;%20Oral%20Implantology%20Kathmandu%20Medical%20College%20Public%20Limited%20%20Kathmandu%20Nepal%22. Consecutive failures: 1
# Warning: ORCID API call failed for query 'family-name:Kosbab AND given-names:Benjamin D. AND affiliation-org-name:"Senior Principal Simpson Gumpertz &amp; Heger  Atlanta Georgia USA"': 500 Server Error:  for url: https://pub.orcid.org/v2.0/search/?defType=lucene&q=family-name:Kosbab%20AND%20given-names:Benjamin%20D.%20AND%20affiliation-org-name:%22Senior%20Principal%20Simpson%20Gumpertz%20&amp;%20Heger%20%20Atlanta%20Georgia%20USA%22. Consecutive failures: 1
# Warning: ORCID API call failed for query 'family-name:Zhang AND given-names:Jianduan AND affiliation-org-name:"Key Laboratory of Environment and Health, Ministry of Education &amp; Ministry of Environmental Protection, and State Key Laboratory of Environmental Health (Incubation), School of Public Health Tongji Medical College, Huazhong University of Science and Technology  Wuhan China"': 500 Server Error:  for url: https://pub.orcid.org/v2.0/search/?defType=lucene&q=family-name:Zhang%20AND%20given-names:Jianduan%20AND%20affiliation-org-name:%22Key%20Laboratory%20of%20Environment%20and%20Health,%20Ministry%20of%20Education%20&amp;%20Ministry%20of%20Environmental%20Protection,%20and%20State%20Key%20Laboratory%20of%20Environmental%20Health%20(Incubation),%20School%20of%20Public%20Health%20Tongji%20Medical%20College,%20Huazhong%20University%20of%20Science%20and%20Technology%20%20Wuhan%20China%22. Consecutive failures: 1
# Warning: ORCID API call failed for query 'family-name:Rieborn AND given-names:Amy AND affiliation-org-name:"Department of Clinical Pharmacy &amp; Toxicology Leiden University Medical Center  Leiden The Netherlands"': 500 Server Error:  for url: https://pub.orcid.org/v2.0/search/?defType=lucene&q=family-name:Rieborn%20AND%20given-names:Amy%20AND%20affiliation-org-name:%22Department%20of%20Clinical%20Pharmacy%20&amp;%20Toxicology%20Leiden%20University%20Medical%20Center%20%20Leiden%20The%20Netherlands%22. Consecutive failures: 1
# Warning: ORCID API call failed for query 'family-name:Giraud AND given-names:Eline L. AND affiliation-org-name:"Department of Clinical Pharmacy &amp; Toxicology Leiden University Medical Center  Leiden The Netherlands"': 500 Server Error:  for url: https://pub.orcid.org/v2.0/search/?defType=lucene&q=family-name:Giraud%20AND%20given-names:Eline%20L.%20AND%20affiliation-org-name:%22Department%20of%20Clinical%20Pharmacy%20&amp;%20Toxicology%20Leiden%20University%20Medical%20Center%20%20Leiden%20The%20Netherlands%22. Consecutive failures: 1
# Warning: ORCID API call failed for query 'family-name:van Gelder AND given-names:Teun AND affiliation-org-name:"Department of Clinical Pharmacy &amp; Toxicology Leiden University Medical Center  Leiden The Netherlands"': 500 Server Error:  for url: https://pub.orcid.org/v2.0/search/?defType=lucene&q=family-name:van%20Gelder%20AND%20given-names:Teun%20AND%20affiliation-org-name:%22Department%20of%20Clinical%20Pharmacy%20&amp;%20Toxicology%20Leiden%20University%20Medical%20Center%20%20Leiden%20The%20Netherlands%22. Consecutive failures: 1
# Warning: ORCID API call failed for query 'family-name:Moes AND given-names:Dirk Jan A. R. AND affiliation-org-name:"Department of Clinical Pharmacy &amp; Toxicology Leiden University Medical Center  Leiden The Netherlands"': 500 Server Error:  for url: https://pub.orcid.org/v2.0/search/?defType=lucene&q=family-name:Moes%20AND%20given-names:Dirk%20Jan%20A.%20R.%20AND%20affiliation-org-name:%22Department%20of%20Clinical%20Pharmacy%20&amp;%20Toxicology%20Leiden%20University%20Medical%20Center%20%20Leiden%20The%20Netherlands%22. Consecutive failures: 1
# Warning: ORCID API call failed for query 'family-name:Faes AND given-names:Matthias G. R. AND affiliation-org-name:"International Joint Research Center for Resilient Infrastructure &amp; International Joint Research Center for Engineering Reliability and Stochastic Mechanics Tongji University  Shanghai PR China"': 500 Server Error:  for url: https://pub.orcid.org/v2.0/search/?defType=lucene&q=family-name:Faes%20AND%20given-names:Matthias%20G.%20R.%20AND%20affiliation-org-name:%22International%20Joint%20Research%20Center%20for%20Resilient%20Infrastructure%20&amp;%20International%20Joint%20Research%20Center%20for%20Engineering%20Reliability%20and%20Stochastic%20Mechanics%20Tongji%20University%20%20Shanghai%20PR%20China%22. Consecutive failures: 1
# Warning: ORCID API call failed for query 'family-name:Fukushima AND given-names:Takafumi AND affiliation-org-name:"Department of Urology, Graduate School of Biomedical &amp; Health Sciences Hiroshima University Hiroshima Japan"': 500 Server Error:  for url: https://pub.orcid.org/v2.0/search/?defType=lucene&q=family-name:Fukushima%20AND%20given-names:Takafumi%20AND%20affiliation-org-name:%22Department%20of%20Urology,%20Graduate%20School%20of%20Biomedical%20&amp;%20Health%20Sciences%20Hiroshima%20University%20Hiroshima%20Japan%22. Consecutive failures: 1
# Warning: ORCID API call failed for query 'family-name:Goto AND given-names:Keisuke AND affiliation-org-name:"Department of Urology, Graduate School of Biomedical &amp; Health Sciences Hiroshima University Hiroshima Japan"': 500 Server Error:  for url: https://pub.orcid.org/v2.0/search/?defType=lucene&q=family-name:Goto%20AND%20given-names:Keisuke%20AND%20affiliation-org-name:%22Department%20of%20Urology,%20Graduate%20School%20of%20Biomedical%20&amp;%20Health%20Sciences%20Hiroshima%20University%20Hiroshima%20Japan%22. Consecutive failures: 1
# Warning: ORCID API call failed for query 'family-name:Nakano AND given-names:Yoshinori AND affiliation-org-name:"Department of Urology, Graduate School of Biomedical &amp; Health Sciences Hiroshima University Hiroshima Japan"': 500 Server Error:  for url: https://pub.orcid.org/v2.0/search/?defType=lucene&q=family-name:Nakano%20AND%20given-names:Yoshinori%20AND%20affiliation-org-name:%22Department%20of%20Urology,%20Graduate%20School%20of%20Biomedical%20&amp;%20Health%20Sciences%20Hiroshima%20University%20Hiroshima%20Japan%22. Consecutive failures: 1
# Warning: ORCID API call failed for query 'family-name:Tasaka AND given-names:Shinsaku AND affiliation-org-name:"Department of Urology, Graduate School of Biomedical &amp; Health Sciences Hiroshima University Hiroshima Japan"': 500 Server Error:  for url: https://pub.orcid.org/v2.0/search/?defType=lucene&q=family-name:Tasaka%20AND%20given-names:Shinsaku%20AND%20affiliation-org-name:%22Department%20of%20Urology,%20Graduate%20School%20of%20Biomedical%20&amp;%20Health%20Sciences%20Hiroshima%20University%20Hiroshima%20Japan%22. Consecutive failures: 1
# Warning: ORCID API call failed for query 'family-name:Iwane AND given-names:Kyohsuke AND affiliation-org-name:"Department of Urology, Graduate School of Biomedical &amp; Health Sciences Hiroshima University Hiroshima Japan"': 500 Server Error:  for url: https://pub.orcid.org/v2.0/search/?defType=lucene&q=family-name:Iwane%20AND%20given-names:Kyohsuke%20AND%20affiliation-org-name:%22Department%20of%20Urology,%20Graduate%20School%20of%20Biomedical%20&amp;%20Health%20Sciences%20Hiroshima%20University%20Hiroshima%20Japan%22. Consecutive failures: 1
# Warning: ORCID API call failed for query 'family-name:Tasaka AND given-names:Ryo AND affiliation-org-name:"Department of Urology, Graduate School of Biomedical &amp; Health Sciences Hiroshima University Hiroshima Japan"': 500 Server Error:  for url: https://pub.orcid.org/v2.0/search/?defType=lucene&q=family-name:Tasaka%20AND%20given-names:Ryo%20AND%20affiliation-org-name:%22Department%20of%20Urology,%20Graduate%20School%20of%20Biomedical%20&amp;%20Health%20Sciences%20Hiroshima%20University%20Hiroshima%20Japan%22. Consecutive failures: 1
# Warning: ORCID API call failed for query 'family-name:Kobatake AND given-names:Kohei AND affiliation-org-name:"Department of Urology, Graduate School of Biomedical &amp; Health Sciences Hiroshima University Hiroshima Japan"': 500 Server Error:  for url: https://pub.orcid.org/v2.0/search/?defType=lucene&q=family-name:Kobatake%20AND%20given-names:Kohei%20AND%20affiliation-org-name:%22Department%20of%20Urology,%20Graduate%20School%20of%20Biomedical%20&amp;%20Health%20Sciences%20Hiroshima%20University%20Hiroshima%20Japan%22. Consecutive failures: 1
# Warning: ORCID API call failed for query 'family-name:Goriki AND given-names:Akihiro AND affiliation-org-name:"Department of Urology, Graduate School of Biomedical &amp; Health Sciences Hiroshima University Hiroshima Japan"': 500 Server Error:  for url: https://pub.orcid.org/v2.0/search/?defType=lucene&q=family-name:Goriki%20AND%20given-names:Akihiro%20AND%20affiliation-org-name:%22Department%20of%20Urology,%20Graduate%20School%20of%20Biomedical%20&amp;%20Health%20Sciences%20Hiroshima%20University%20Hiroshima%20Japan%22. Consecutive failures: 1
# Warning: ORCID API call failed for query 'family-name:Clair Nelson AND given-names:Hayes AND affiliation-org-name:"Department of Gastroenterology, Graduate School of Biomedical &amp; Health Sciences Hiroshima University Hiroshima Japan"': 500 Server Error:  for url: https://pub.orcid.org/v2.0/search/?defType=lucene&q=family-name:Clair%20Nelson%20AND%20given-names:Hayes%20AND%20affiliation-org-name:%22Department%20of%20Gastroenterology,%20Graduate%20School%20of%20Biomedical%20&amp;%20Health%20Sciences%20Hiroshima%20University%20Hiroshima%20Japan%22. Consecutive failures: 1
# Warning: ORCID API call failed for query 'family-name:Hinata AND given-names:Nobuyuki AND affiliation-org-name:"Department of Urology, Graduate School of Biomedical &amp; Health Sciences Hiroshima University Hiroshima Japan"': 500 Server Error:  for url: https://pub.orcid.org/v2.0/search/?defType=lucene&q=family-name:Hinata%20AND%20given-names:Nobuyuki%20AND%20affiliation-org-name:%22Department%20of%20Urology,%20Graduate%20School%20of%20Biomedical%20&amp;%20Health%20Sciences%20Hiroshima%20University%20Hiroshima%20Japan%22. Consecutive failures: 1
# Warning: ORCID API call failed for query 'family-name:Lasserson AND given-names:Toby J AND affiliation-org-name:"Evidence Production & Methods Directorate; Cochrane Central Executive; London UK"': 500 Server Error:  for url: https://pub.orcid.org/v2.0/search/?defType=lucene&q=family-name:Lasserson%20AND%20given-names:Toby%20J%20AND%20affiliation-org-name:%22Evidence%20Production%20&%20Methods%20Directorate;%20Cochrane%20Central%20Executive;%20London%20UK%22. Consecutive failures: 1
# Warning: ORCID API call failed for query 'family-name:Tang AND given-names:Yan‐Ling AND affiliation-org-name:"Key Laboratory of Medicinal Chemistry for Natural Resources of Ministry of Education, Yunnan Characteristic Plant Extraction Laboratory Co., Ltd., Yunnan Research &amp; Development Centre for Natural Products, State Key Laboratory for Conservation and Utilization of Bio‐Resources in Yunnan, School of Chemical Science and Technology and School of Pharmacy Yunnan University Kunming P. R. China"': 500 Server Error:  for url: https://pub.orcid.org/v2.0/search/?defType=lucene&q=family-name:Tang%20AND%20given-names:Yan%E2%80%90Ling%20AND%20affiliation-org-name:%22Key%20Laboratory%20of%20Medicinal%20Chemistry%20for%20Natural%20Resources%20of%20Ministry%20of%20Education,%20Yunnan%20Characteristic%20Plant%20Extraction%20Laboratory%20Co.,%20Ltd.,%20Yunnan%20Research%20&amp;%20Development%20Centre%20for%20Natural%20Products,%20State%20Key%20Laboratory%20for%20Conservation%20and%20Utilization%20of%20Bio%E2%80%90Resources%20in%20Yunnan,%20School%20of%20Chemical%20Science%20and%20Technology%20and%20School%20of%20Pharmacy%20Yunnan%20University%20Kunming%20P.%20R.%20China%22. Consecutive failures: 1
# Warning: ORCID API call failed for query 'family-name:Ji AND given-names:Xue‐Ting AND affiliation-org-name:"Key Laboratory of Medicinal Chemistry for Natural Resources of Ministry of Education, Yunnan Characteristic Plant Extraction Laboratory Co., Ltd., Yunnan Research &amp; Development Centre for Natural Products, State Key Laboratory for Conservation and Utilization of Bio‐Resources in Yunnan, School of Chemical Science and Technology and School of Pharmacy Yunnan University Kunming P. R. China"': 500 Server Error:  for url: https://pub.orcid.org/v2.0/search/?defType=lucene&q=family-name:Ji%20AND%20given-names:Xue%E2%80%90Ting%20AND%20affiliation-org-name:%22Key%20Laboratory%20of%20Medicinal%20Chemistry%20for%20Natural%20Resources%20of%20Ministry%20of%20Education,%20Yunnan%20Characteristic%20Plant%20Extraction%20Laboratory%20Co.,%20Ltd.,%20Yunnan%20Research%20&amp;%20Development%20Centre%20for%20Natural%20Products,%20State%20Key%20Laboratory%20for%20Conservation%20and%20Utilization%20of%20Bio%E2%80%90Resources%20in%20Yunnan,%20School%20of%20Chemical%20Science%20and%20Technology%20and%20School%20of%20Pharmacy%20Yunnan%20University%20Kunming%20P.%20R.%20China%22. Consecutive failures: 1
# Warning: ORCID API call failed for query 'family-name:Ma AND given-names:Yan‐Zi AND affiliation-org-name:"Key Laboratory of Medicinal Chemistry for Natural Resources of Ministry of Education, Yunnan Characteristic Plant Extraction Laboratory Co., Ltd., Yunnan Research &amp; Development Centre for Natural Products, State Key Laboratory for Conservation and Utilization of Bio‐Resources in Yunnan, School of Chemical Science and Technology and School of Pharmacy Yunnan University Kunming P. R. China"': 500 Server Error:  for url: https://pub.orcid.org/v2.0/search/?defType=lucene&q=family-name:Ma%20AND%20given-names:Yan%E2%80%90Zi%20AND%20affiliation-org-name:%22Key%20Laboratory%20of%20Medicinal%20Chemistry%20for%20Natural%20Resources%20of%20Ministry%20of%20Education,%20Yunnan%20Characteristic%20Plant%20Extraction%20Laboratory%20Co.,%20Ltd.,%20Yunnan%20Research%20&amp;%20Development%20Centre%20for%20Natural%20Products,%20State%20Key%20Laboratory%20for%20Conservation%20and%20Utilization%20of%20Bio%E2%80%90Resources%20in%20Yunnan,%20School%20of%20Chemical%20Science%20and%20Technology%20and%20School%20of%20Pharmacy%20Yunnan%20University%20Kunming%20P.%20R.%20China%22. Consecutive failures: 1
# Warning: ORCID API call failed for query 'family-name:Wu AND given-names:Xue‐Wen AND affiliation-org-name:"Key Laboratory of Medicinal Chemistry for Natural Resources of Ministry of Education, Yunnan Characteristic Plant Extraction Laboratory Co., Ltd., Yunnan Research &amp; Development Centre for Natural Products, State Key Laboratory for Conservation and Utilization of Bio‐Resources in Yunnan, School of Chemical Science and Technology and School of Pharmacy Yunnan University Kunming P. R. China"': 500 Server Error:  for url: https://pub.orcid.org/v2.0/search/?defType=lucene&q=family-name:Wu%20AND%20given-names:Xue%E2%80%90Wen%20AND%20affiliation-org-name:%22Key%20Laboratory%20of%20Medicinal%20Chemistry%20for%20Natural%20Resources%20of%20Ministry%20of%20Education,%20Yunnan%20Characteristic%20Plant%20Extraction%20Laboratory%20Co.,%20Ltd.,%20Yunnan%20Research%20&amp;%20Development%20Centre%20for%20Natural%20Products,%20State%20Key%20Laboratory%20for%20Conservation%20and%20Utilization%20of%20Bio%E2%80%90Resources%20in%20Yunnan,%20School%20of%20Chemical%20Science%20and%20Technology%20and%20School%20of%20Pharmacy%20Yunnan%20University%20Kunming%20P.%20R.%20China%22. Consecutive failures: 1
# Warning: ORCID API call failed for query 'family-name:Zeb AND given-names:Muhammad Aurang AND affiliation-org-name:"Key Laboratory of Medicinal Chemistry for Natural Resources of Ministry of Education, Yunnan Characteristic Plant Extraction Laboratory Co., Ltd., Yunnan Research &amp; Development Centre for Natural Products, State Key Laboratory for Conservation and Utilization of Bio‐Resources in Yunnan, School of Chemical Science and Technology and School of Pharmacy Yunnan University Kunming P. R. China"': 500 Server Error:  for url: https://pub.orcid.org/v2.0/search/?defType=lucene&q=family-name:Zeb%20AND%20given-names:Muhammad%20Aurang%20AND%20affiliation-org-name:%22Key%20Laboratory%20of%20Medicinal%20Chemistry%20for%20Natural%20Resources%20of%20Ministry%20of%20Education,%20Yunnan%20Characteristic%20Plant%20Extraction%20Laboratory%20Co.,%20Ltd.,%20Yunnan%20Research%20&amp;%20Development%20Centre%20for%20Natural%20Products,%20State%20Key%20Laboratory%20for%20Conservation%20and%20Utilization%20of%20Bio%E2%80%90Resources%20in%20Yunnan,%20School%20of%20Chemical%20Science%20and%20Technology%20and%20School%20of%20Pharmacy%20Yunnan%20University%20Kunming%20P.%20R.%20China%22. Consecutive failures: 1
# Warning: ORCID API call failed for query 'family-name:Kong AND given-names:Yuan‐Lin AND affiliation-org-name:"Key Laboratory of Medicinal Chemistry for Natural Resources of Ministry of Education, Yunnan Characteristic Plant Extraction Laboratory Co., Ltd., Yunnan Research &amp; Development Centre for Natural Products, State Key Laboratory for Conservation and Utilization of Bio‐Resources in Yunnan, School of Chemical Science and Technology and School of Pharmacy Yunnan University Kunming P. R. China"': 500 Server Error:  for url: https://pub.orcid.org/v2.0/search/?defType=lucene&q=family-name:Kong%20AND%20given-names:Yuan%E2%80%90Lin%20AND%20affiliation-org-name:%22Key%20Laboratory%20of%20Medicinal%20Chemistry%20for%20Natural%20Resources%20of%20Ministry%20of%20Education,%20Yunnan%20Characteristic%20Plant%20Extraction%20Laboratory%20Co.,%20Ltd.,%20Yunnan%20Research%20&amp;%20Development%20Centre%20for%20Natural%20Products,%20State%20Key%20Laboratory%20for%20Conservation%20and%20Utilization%20of%20Bio%E2%80%90Resources%20in%20Yunnan,%20School%20of%20Chemical%20Science%20and%20Technology%20and%20School%20of%20Pharmacy%20Yunnan%20University%20Kunming%20P.%20R.%20China%22. Consecutive failures: 1
# Warning: ORCID API call failed for query 'family-name:Liang AND given-names:Zhong‐Dan AND affiliation-org-name:"Key Laboratory of Medicinal Chemistry for Natural Resources of Ministry of Education, Yunnan Characteristic Plant Extraction Laboratory Co., Ltd., Yunnan Research &amp; Development Centre for Natural Products, State Key Laboratory for Conservation and Utilization of Bio‐Resources in Yunnan, School of Chemical Science and Technology and School of Pharmacy Yunnan University Kunming P. R. China"': 500 Server Error:  for url: https://pub.orcid.org/v2.0/search/?defType=lucene&q=family-name:Liang%20AND%20given-names:Zhong%E2%80%90Dan%20AND%20affiliation-org-name:%22Key%20Laboratory%20of%20Medicinal%20Chemistry%20for%20Natural%20Resources%20of%20Ministry%20of%20Education,%20Yunnan%20Characteristic%20Plant%20Extraction%20Laboratory%20Co.,%20Ltd.,%20Yunnan%20Research%20&amp;%20Development%20Centre%20for%20Natural%20Products,%20State%20Key%20Laboratory%20for%20Conservation%20and%20Utilization%20of%20Bio%E2%80%90Resources%20in%20Yunnan,%20School%20of%20Chemical%20Science%20and%20Technology%20and%20School%20of%20Pharmacy%20Yunnan%20University%20Kunming%20P.%20R.%20China%22. Consecutive failures: 1
# Warning: ORCID API call failed for query 'family-name:Li AND given-names:Xiao‐Li AND affiliation-org-name:"Key Laboratory of Medicinal Chemistry for Natural Resources of Ministry of Education, Yunnan Characteristic Plant Extraction Laboratory Co., Ltd., Yunnan Research &amp; Development Centre for Natural Products, State Key Laboratory for Conservation and Utilization of Bio‐Resources in Yunnan, School of Chemical Science and Technology and School of Pharmacy Yunnan University Kunming P. R. China"': 500 Server Error:  for url: https://pub.orcid.org/v2.0/search/?defType=lucene&q=family-name:Li%20AND%20given-names:Xiao%E2%80%90Li%20AND%20affiliation-org-name:%22Key%20Laboratory%20of%20Medicinal%20Chemistry%20for%20Natural%20Resources%20of%20Ministry%20of%20Education,%20Yunnan%20Characteristic%20Plant%20Extraction%20Laboratory%20Co.,%20Ltd.,%20Yunnan%20Research%20&amp;%20Development%20Centre%20for%20Natural%20Products,%20State%20Key%20Laboratory%20for%20Conservation%20and%20Utilization%20of%20Bio%E2%80%90Resources%20in%20Yunnan,%20School%20of%20Chemical%20Science%20and%20Technology%20and%20School%20of%20Pharmacy%20Yunnan%20University%20Kunming%20P.%20R.%20China%22. Consecutive failures: 1
# Warning: ORCID API call failed for query 'family-name:Zhang AND given-names:Xing‐Jie AND affiliation-org-name:"Key Laboratory of Medicinal Chemistry for Natural Resources of Ministry of Education, Yunnan Characteristic Plant Extraction Laboratory Co., Ltd., Yunnan Research &amp; Development Centre for Natural Products, State Key Laboratory for Conservation and Utilization of Bio‐Resources in Yunnan, School of Chemical Science and Technology and School of Pharmacy Yunnan University Kunming P. R. China"': 500 Server Error:  for url: https://pub.orcid.org/v2.0/search/?defType=lucene&q=family-name:Zhang%20AND%20given-names:Xing%E2%80%90Jie%20AND%20affiliation-org-name:%22Key%20Laboratory%20of%20Medicinal%20Chemistry%20for%20Natural%20Resources%20of%20Ministry%20of%20Education,%20Yunnan%20Characteristic%20Plant%20Extraction%20Laboratory%20Co.,%20Ltd.,%20Yunnan%20Research%20&amp;%20Development%20Centre%20for%20Natural%20Products,%20State%20Key%20Laboratory%20for%20Conservation%20and%20Utilization%20of%20Bio%E2%80%90Resources%20in%20Yunnan,%20School%20of%20Chemical%20Science%20and%20Technology%20and%20School%20of%20Pharmacy%20Yunnan%20University%20Kunming%20P.%20R.%20China%22. Consecutive failures: 1
# Warning: ORCID API call failed for query 'family-name:Xiao AND given-names:Wei‐Lie AND affiliation-org-name:"Key Laboratory of Medicinal Chemistry for Natural Resources of Ministry of Education, Yunnan Characteristic Plant Extraction Laboratory Co., Ltd., Yunnan Research &amp; Development Centre for Natural Products, State Key Laboratory for Conservation and Utilization of Bio‐Resources in Yunnan, School of Chemical Science and Technology and School of Pharmacy Yunnan University Kunming P. R. China"': 500 Server Error:  for url: https://pub.orcid.org/v2.0/search/?defType=lucene&q=family-name:Xiao%20AND%20given-names:Wei%E2%80%90Lie%20AND%20affiliation-org-name:%22Key%20Laboratory%20of%20Medicinal%20Chemistry%20for%20Natural%20Resources%20of%20Ministry%20of%20Education,%20Yunnan%20Characteristic%20Plant%20Extraction%20Laboratory%20Co.,%20Ltd.,%20Yunnan%20Research%20&amp;%20Development%20Centre%20for%20Natural%20Products,%20State%20Key%20Laboratory%20for%20Conservation%20and%20Utilization%20of%20Bio%E2%80%90Resources%20in%20Yunnan,%20School%20of%20Chemical%20Science%20and%20Technology%20and%20School%20of%20Pharmacy%20Yunnan%20University%20Kunming%20P.%20R.%20China%22. Consecutive failures: 1
# Warning: ORCID API call failed for query 'family-name:Hu AND given-names:Yaolin AND affiliation-org-name:"Nanophotonics Research Center Shenzhen Key Laboratory of Micro‐Scale Optical Information Technology Institute of Microscale Optoelectronics &amp; State Key Laboratory of Radio Frequency Heterogeneous Integration Shenzhen University  Shenzhen 518060 China"': 500 Server Error:  for url: https://pub.orcid.org/v2.0/search/?defType=lucene&q=family-name:Hu%20AND%20given-names:Yaolin%20AND%20affiliation-org-name:%22Nanophotonics%20Research%20Center%20Shenzhen%20Key%20Laboratory%20of%20Micro%E2%80%90Scale%20Optical%20Information%20Technology%20Institute%20of%20Microscale%20Optoelectronics%20&amp;%20State%20Key%20Laboratory%20of%20Radio%20Frequency%20Heterogeneous%20Integration%20Shenzhen%20University%20%20Shenzhen%20518060%20China%22. Consecutive failures: 1
# Warning: ORCID API call failed for query 'family-name:Wu AND given-names:Ruitao AND affiliation-org-name:"Nanophotonics Research Center Shenzhen Key Laboratory of Micro‐Scale Optical Information Technology Institute of Microscale Optoelectronics &amp; State Key Laboratory of Radio Frequency Heterogeneous Integration Shenzhen University  Shenzhen 518060 China"': 500 Server Error:  for url: https://pub.orcid.org/v2.0/search/?defType=lucene&q=family-name:Wu%20AND%20given-names:Ruitao%20AND%20affiliation-org-name:%22Nanophotonics%20Research%20Center%20Shenzhen%20Key%20Laboratory%20of%20Micro%E2%80%90Scale%20Optical%20Information%20Technology%20Institute%20of%20Microscale%20Optoelectronics%20&amp;%20State%20Key%20Laboratory%20of%20Radio%20Frequency%20Heterogeneous%20Integration%20Shenzhen%20University%20%20Shenzhen%20518060%20China%22. Consecutive failures: 1
# Warning: ORCID API call failed for query 'family-name:Li AND given-names:Zhenli AND affiliation-org-name:"Nanophotonics Research Center Shenzhen Key Laboratory of Micro‐Scale Optical Information Technology Institute of Microscale Optoelectronics &amp; State Key Laboratory of Radio Frequency Heterogeneous Integration Shenzhen University  Shenzhen 518060 China"': 500 Server Error:  for url: https://pub.orcid.org/v2.0/search/?defType=lucene&q=family-name:Li%20AND%20given-names:Zhenli%20AND%20affiliation-org-name:%22Nanophotonics%20Research%20Center%20Shenzhen%20Key%20Laboratory%20of%20Micro%E2%80%90Scale%20Optical%20Information%20Technology%20Institute%20of%20Microscale%20Optoelectronics%20&amp;%20State%20Key%20Laboratory%20of%20Radio%20Frequency%20Heterogeneous%20Integration%20Shenzhen%20University%20%20Shenzhen%20518060%20China%22. Consecutive failures: 1
# Warning: ORCID API call failed for query 'family-name:Du AND given-names:Luping AND affiliation-org-name:"Nanophotonics Research Center Shenzhen Key Laboratory of Micro‐Scale Optical Information Technology Institute of Microscale Optoelectronics &amp; State Key Laboratory of Radio Frequency Heterogeneous Integration Shenzhen University  Shenzhen 518060 China"': 500 Server Error:  for url: https://pub.orcid.org/v2.0/search/?defType=lucene&q=family-name:Du%20AND%20given-names:Luping%20AND%20affiliation-org-name:%22Nanophotonics%20Research%20Center%20Shenzhen%20Key%20Laboratory%20of%20Micro%E2%80%90Scale%20Optical%20Information%20Technology%20Institute%20of%20Microscale%20Optoelectronics%20&amp;%20State%20Key%20Laboratory%20of%20Radio%20Frequency%20Heterogeneous%20Integration%20Shenzhen%20University%20%20Shenzhen%20518060%20China%22. Consecutive failures: 1
# ...
# Warning: ORCID API call failed for query 'family-name:Liu AND given-names:Chunli AND affiliation-org-name:"Department of Infectious Disease, Affiliated Infectious Disease Hospital of Zhengzhou University (Henan Infectious Disease Hospital, The Sixth People&apos;s Hospital of Zhengzhou), Zhengzhou 450015, China;"': 500 Server Error:  for url: https://pub.orcid.org/v2.0/search/?defType=lucene&q=family-name:Liu%20AND%20given-names:Chunli%20AND%20affiliation-org-name:%22Department%20of%20Infectious%20Disease,%20Affiliated%20Infectious%20Disease%20Hospital%20of%20Zhengzhou%20University%20(Henan%20Infectious%20Disease%20Hospital,%20The%20Sixth%20People&apos;s%20Hospital%20of%20Zhengzhou),%20Zhengzhou%20450015,%20China;%22. Consecutive failures: 1
# Warning: ORCID API call failed for query 'family-name:Yuwu AND given-names:Ding AND affiliation-org-name:"Department of Rehabilitation, Seventh People&apos;s Hospital of Shanghai University of Traditional Chinese Medicine, Shanghai 200137, China;"': 500 Server Error:  for url: https://pub.orcid.org/v2.0/search/?defType=lucene&q=family-name:Yuwu%20AND%20given-names:Ding%20AND%20affiliation-org-name:%22Department%20of%20Rehabilitation,%20Seventh%20People&apos;s%20Hospital%20of%20Shanghai%20University%20of%20Traditional%20Chinese%20Medicine,%20Shanghai%20200137,%20China;%22. Consecutive failures: 1
# Warning: ORCID API call failed for query 'family-name:Lixi AND given-names:Chu AND affiliation-org-name:"Department of Rehabilitation, Seventh People&apos;s Hospital of Shanghai University of Traditional Chinese Medicine, Shanghai 200137, China;"': 500 Server Error:  for url: https://pub.orcid.org/v2.0/search/?defType=lucene&q=family-name:Lixi%20AND%20given-names:Chu%20AND%20affiliation-org-name:%22Department%20of%20Rehabilitation,%20Seventh%20People&apos;s%20Hospital%20of%20Shanghai%20University%20of%20Traditional%20Chinese%20Medicine,%20Shanghai%20200137,%20China;%22. Consecutive failures: 1
# Warning: ORCID API call failed for query 'family-name:Kun AND given-names:Yang AND affiliation-org-name:"Department of Rehabilitation, Seventh People&apos;s Hospital of Shanghai University of Traditional Chinese Medicine, Shanghai 200137, China;"': 500 Server Error:  for url: https://pub.orcid.org/v2.0/search/?defType=lucene&q=family-name:Kun%20AND%20given-names:Yang%20AND%20affiliation-org-name:%22Department%20of%20Rehabilitation,%20Seventh%20People&apos;s%20Hospital%20of%20Shanghai%20University%20of%20Traditional%20Chinese%20Medicine,%20Shanghai%20200137,%20China;%22. Consecutive failures: 1
# Warning: ORCID API call failed for query 'family-name:Minqian AND given-names:Wei AND affiliation-org-name:"Department of Rehabilitation, Seventh People&apos;s Hospital of Shanghai University of Traditional Chinese Medicine, Shanghai 200137, China;"': 500 Server Error:  for url: https://pub.orcid.org/v2.0/search/?defType=lucene&q=family-name:Minqian%20AND%20given-names:Wei%20AND%20affiliation-org-name:%22Department%20of%20Rehabilitation,%20Seventh%20People&apos;s%20Hospital%20of%20Shanghai%20University%20of%20Traditional%20Chinese%20Medicine,%20Shanghai%20200137,%20China;%22. Consecutive failures: 1
# Warning: ORCID API call failed for query 'family-name:Xiaoming AND given-names:Yu AND affiliation-org-name:"Department of Rehabilitation, Seventh People&apos;s Hospital of Shanghai University of Traditional Chinese Medicine, Shanghai 200137, China;"': 500 Server Error:  for url: https://pub.orcid.org/v2.0/search/?defType=lucene&q=family-name:Xiaoming%20AND%20given-names:Yu%20AND%20affiliation-org-name:%22Department%20of%20Rehabilitation,%20Seventh%20People&apos;s%20Hospital%20of%20Shanghai%20University%20of%20Traditional%20Chinese%20Medicine,%20Shanghai%20200137,%20China;%22. Consecutive failures: 1
# Warning: ORCID API call failed for query 'family-name:Liming AND given-names:Jiang AND affiliation-org-name:"Department of Rehabilitation, Seventh People&apos;s Hospital of Shanghai University of Traditional Chinese Medicine, Shanghai 200137, China;"': 500 Server Error:  for url: https://pub.orcid.org/v2.0/search/?defType=lucene&q=family-name:Liming%20AND%20given-names:Jiang%20AND%20affiliation-org-name:%22Department%20of%20Rehabilitation,%20Seventh%20People&apos;s%20Hospital%20of%20Shanghai%20University%20of%20Traditional%20Chinese%20Medicine,%20Shanghai%20200137,%20China;%22. Consecutive failures: 1
# Warning: ORCID API call failed for query 'family-name:Xiao-Min AND given-names:Ding AND affiliation-org-name:"School of Physical Education, Jinggangshan University, Ji&apos;an 343009, China;"': 500 Server Error:  for url: https://pub.orcid.org/v2.0/search/?defType=lucene&q=family-name:Xiao-Min%20AND%20given-names:Ding%20AND%20affiliation-org-name:%22School%20of%20Physical%20Education,%20Jinggangshan%20University,%20Ji&apos;an%20343009,%20China;%22. Consecutive failures: 1
# Warning: ORCID API call failed for query 'family-name:Chong-Lin AND given-names:Zhang AND affiliation-org-name:"School of Physical Education, Jiangxi Normal University, Nanchang 330027, China; School of Physical Education, Jinggangshan University, Ji&apos;an 343009, China;"': 500 Server Error:  for url: https://pub.orcid.org/v2.0/search/?defType=lucene&q=family-name:Chong-Lin%20AND%20given-names:Zhang%20AND%20affiliation-org-name:%22School%20of%20Physical%20Education,%20Jiangxi%20Normal%20University,%20Nanchang%20330027,%20China;%20School%20of%20Physical%20Education,%20Jinggangshan%20University,%20Ji&apos;an%20343009,%20China;%22. Consecutive failures: 1
# Warning: ORCID API call failed for query 'family-name:Spiegelhofer AND given-names:Mathias AND affiliation-org-name:"Dsm-firmenich, Animal Nutrition and Health, R&D Center, Tulln 3430, Austria;"': 500 Server Error:  for url: https://pub.orcid.org/v2.0/search/?defType=lucene&q=family-name:Spiegelhofer%20AND%20given-names:Mathias%20AND%20affiliation-org-name:%22Dsm-firmenich,%20Animal%20Nutrition%20and%20Health,%20R&D%20Center,%20Tulln%203430,%20Austria;%22. Consecutive failures: 1
# Warning: ORCID API call failed for query 'family-name:Ren AND given-names:Wen AND affiliation-org-name:"Dsm-firmenich, Animal Nutrition and Health, R&D Center, Bazhou 065799, China;"': 500 Server Error:  for url: https://pub.orcid.org/v2.0/search/?defType=lucene&q=family-name:Ren%20AND%20given-names:Wen%20AND%20affiliation-org-name:%22Dsm-firmenich,%20Animal%20Nutrition%20and%20Health,%20R&D%20Center,%20Bazhou%20065799,%20China;%22. Consecutive failures: 1
# Warning: ORCID API call failed for query 'family-name:Sanbao AND given-names:Dong AND affiliation-org-name:"Xi&apos;an Petroleum University Oil and Gas Field Chemistry Shaanxi Provincial University Engineering Research Center, Xi’an 710065, China;"': 500 Server Error:  for url: https://pub.orcid.org/v2.0/search/?defType=lucene&q=family-name:Sanbao%20AND%20given-names:Dong%20AND%20affiliation-org-name:%22Xi&apos;an%20Petroleum%20University%20Oil%20and%20Gas%20Field%20Chemistry%20Shaanxi%20Provincial%20University%20Engineering%20Research%20Center,%20Xi%E2%80%99an%20710065,%20China;%22. Consecutive failures: 1
# Warning: ORCID API call failed for query 'family-name:Qian-qian AND given-names:Chen AND affiliation-org-name:"Pediatric Department, Hainan Women and Children&apos;s Medical Center, Haikou 570100, China;"': 500 Server Error:  for url: https://pub.orcid.org/v2.0/search/?defType=lucene&q=family-name:Qian-qian%20AND%20given-names:Chen%20AND%20affiliation-org-name:%22Pediatric%20Department,%20Hainan%20Women%20and%20Children&apos;s%20Medical%20Center,%20Haikou%20570100,%20China;%22. Consecutive failures: 1
# Warning: ORCID API call failed for query 'family-name:Xiao-li AND given-names:Zhao AND affiliation-org-name:"Pediatric Department, Hainan Women and Children&apos;s Medical Center, Haikou 570100, China;"': 500 Server Error:  for url: https://pub.orcid.org/v2.0/search/?defType=lucene&q=family-name:Xiao-li%20AND%20given-names:Zhao%20AND%20affiliation-org-name:%22Pediatric%20Department,%20Hainan%20Women%20and%20Children&apos;s%20Medical%20Center,%20Haikou%20570100,%20China;%22. Consecutive failures: 1
# Warning: ORCID API call failed for query 'family-name:Xiang-yun AND given-names:Zhang AND affiliation-org-name:"Pediatric Department, Hainan Women and Children&apos;s Medical Center, Haikou 570100, China;"': 500 Server Error:  for url: https://pub.orcid.org/v2.0/search/?defType=lucene&q=family-name:Xiang-yun%20AND%20given-names:Zhang%20AND%20affiliation-org-name:%22Pediatric%20Department,%20Hainan%20Women%20and%20Children&apos;s%20Medical%20Center,%20Haikou%20570100,%20China;%22. Consecutive failures: 1
# Warning: ORCID API call failed for query 'family-name:Du-fei AND given-names:Zhang AND affiliation-org-name:"Pediatric Department, Hainan Women and Children&apos;s Medical Center, Haikou 570100, China;"': 500 Server Error:  for url: https://pub.orcid.org/v2.0/search/?defType=lucene&q=family-name:Du-fei%20AND%20given-names:Zhang%20AND%20affiliation-org-name:%22Pediatric%20Department,%20Hainan%20Women%20and%20Children&apos;s%20Medical%20Center,%20Haikou%20570100,%20China;%22. Consecutive failures: 1
# Warning: ORCID API call failed for query 'family-name:Wang AND given-names:Shengdong AND affiliation-org-name:"College of Biological & Environmental Sciences, Zhejiang Wanli University, Ningbo 315100, China;"': 500 Server Error:  for url: https://pub.orcid.org/v2.0/search/?defType=lucene&q=family-name:Wang%20AND%20given-names:Shengdong%20AND%20affiliation-org-name:%22College%20of%20Biological%20&%20Environmental%20Sciences,%20Zhejiang%20Wanli%20University,%20Ningbo%20315100,%20China;%22. Consecutive failures: 1
# Warning: ORCID API call failed for query 'family-name:Xu AND given-names:Xu AND affiliation-org-name:"College of Biological & Environmental Sciences, Zhejiang Wanli University, Ningbo 315100, China;"': 500 Server Error:  for url: https://pub.orcid.org/v2.0/search/?defType=lucene&q=family-name:Xu%20AND%20given-names:Xu%20AND%20affiliation-org-name:%22College%20of%20Biological%20&%20Environmental%20Sciences,%20Zhejiang%20Wanli%20University,%20Ningbo%20315100,%20China;%22. Consecutive failures: 1
# Warning: ORCID API call failed for query 'family-name:Liu AND given-names:Liping AND affiliation-org-name:"College of Biological & Environmental Sciences, Zhejiang Wanli University, Ningbo 315100, China;"': 500 Server Error:  for url: https://pub.orcid.org/v2.0/search/?defType=lucene&q=family-name:Liu%20AND%20given-names:Liping%20AND%20affiliation-org-name:%22College%20of%20Biological%20&%20Environmental%20Sciences,%20Zhejiang%20Wanli%20University,%20Ningbo%20315100,%20China;%22. Consecutive failures: 1
# Warning: ORCID API call failed for query 'family-name:Jian-hua AND given-names:Dai AND affiliation-org-name:"Department of Thoracic Surgery, The First People&apos;s Hospital of Lianyungang, Affiliated Lianyungang Hospital of Xuzhou Medical University, Lianyungang 222002, China;"': 500 Server Error:  for url: https://pub.orcid.org/v2.0/search/?defType=lucene&q=family-name:Jian-hua%20AND%20given-names:Dai%20AND%20affiliation-org-name:%22Department%20of%20Thoracic%20Surgery,%20The%20First%20People&apos;s%20Hospital%20of%20Lianyungang,%20Affiliated%20Lianyungang%20Hospital%20of%20Xuzhou%20Medical%20University,%20Lianyungang%20222002,%20China;%22. Consecutive failures: 1
# Warning: ORCID API call failed for query 'family-name:Jun AND given-names:Zheng AND affiliation-org-name:"Paediatrics Department, Hainan Women and Children&apos;s Medical Center, Haikou 570000, China;"': 500 Server Error:  for url: https://pub.orcid.org/v2.0/search/?defType=lucene&q=family-name:Jun%20AND%20given-names:Zheng%20AND%20affiliation-org-name:%22Paediatrics%20Department,%20Hainan%20Women%20and%20Children&apos;s%20Medical%20Center,%20Haikou%20570000,%20China;%22. Consecutive failures: 1
# Warning: ORCID API call failed for query 'family-name:Xiangyun AND given-names:Zhang AND affiliation-org-name:"Paediatrics Department, Hainan Women and Children&apos;s Medical Center, Haikou 570000, China;"': 500 Server Error:  for url: https://pub.orcid.org/v2.0/search/?defType=lucene&q=family-name:Xiangyun%20AND%20given-names:Zhang%20AND%20affiliation-org-name:%22Paediatrics%20Department,%20Hainan%20Women%20and%20Children&apos;s%20Medical%20Center,%20Haikou%20570000,%20China;%22. Consecutive failures: 1
# Warning: ORCID API call failed for query 'family-name:Roberts AND given-names:Cynthia J. AND affiliation-org-name:"The Department of Ophthalmology &amp; Visual Sciences, Department of Biomedical Engineering, The Ohio State University, Columbus, Ohio."': 500 Server Error:  for url: https://pub.orcid.org/v2.0/search/?defType=lucene&q=family-name:Roberts%20AND%20given-names:Cynthia%20J.%20AND%20affiliation-org-name:%22The%20Department%20of%20Ophthalmology%20&amp;%20Visual%20Sciences,%20Department%20of%20Biomedical%20Engineering,%20The%20Ohio%20State%20University,%20Columbus,%20Ohio.%22. Consecutive failures: 1
# Warning: ORCID API call failed for query 'family-name:Guzman AND given-names:Ariz Amoroso AND affiliation-org-name:"Cedars Sinai Health System, Nursing Research &amp; Quality Improvement,"': 500 Server Error:  for url: https://pub.orcid.org/v2.0/search/?defType=lucene&q=family-name:Guzman%20AND%20given-names:Ariz%20Amoroso%20AND%20affiliation-org-name:%22Cedars%20Sinai%20Health%20System,%20Nursing%20Research%20&amp;%20Quality%20Improvement,%22. Consecutive failures: 1
# Warning: ORCID API call failed for query 'family-name:Coleman AND given-names:Bernice AND affiliation-org-name:"Cedars Sinai Health System, Nursing Research &amp; Quality Improvement,"': 500 Server Error:  for url: https://pub.orcid.org/v2.0/search/?defType=lucene&q=family-name:Coleman%20AND%20given-names:Bernice%20AND%20affiliation-org-name:%22Cedars%20Sinai%20Health%20System,%20Nursing%20Research%20&amp;%20Quality%20Improvement,%22. Consecutive failures: 1
# Warning: ORCID API call failed for query 'family-name:Aronow AND given-names:Harriet AND affiliation-org-name:"Cedars Sinai Health System, Nursing Research &amp; Quality Improvement,"': 500 Server Error:  for url: https://pub.orcid.org/v2.0/search/?defType=lucene&q=family-name:Aronow%20AND%20given-names:Harriet%20AND%20affiliation-org-name:%22Cedars%20Sinai%20Health%20System,%20Nursing%20Research%20&amp;%20Quality%20Improvement,%22. Consecutive failures: 1
# Warning: ORCID API call failed for query 'family-name:Ebanks AND given-names:Andrew R. AND affiliation-org-name:"Division of Gastroenterology, Hepatology and Nutrition, Department of Pediatrics, Ann &amp; Robert H. Lurie Children's Hospital of Chicago, Chicago, Illinois."': 500 Server Error:  for url: https://pub.orcid.org/v2.0/search/?defType=lucene&q=family-name:Ebanks%20AND%20given-names:Andrew%20R.%20AND%20affiliation-org-name:%22Division%20of%20Gastroenterology,%20Hepatology%20and%20Nutrition,%20Department%20of%20Pediatrics,%20Ann%20&amp;%20Robert%20H.%20Lurie%20Children's%20Hospital%20of%20Chicago,%20Chicago,%20Illinois.%22. Consecutive failures: 1
# Found 13483 ORCID records.
# Example ORCID tuples: [('Miro Demol', 'No Affiliation Provided', '0000-0002-5492-2874'), ('Naikoa Aguilar-Amuchastegui', 'No Affiliation Provided', '0000-0002-5072-0079'), ('Gabija Bernotaite', 'No Affiliation Provided', '0009-0004-5550-1109'), ('Mathias Disney', 'No Affiliation Provided', '0000-0002-2407-4026'), ('Laura Duncanson', 'No Affiliation Provided', '0000-0003-4031-3493')]

# %%
with open("orcid_tuples.txt", "w", encoding="utf8") as g:
  for author in orcid_tuples:
    cleaned = [normalize(v) for v in author]
    values_sql = ", ".join(sql_literal(v) for v in cleaned)

    g.write(
      f"INSERT INTO Author VALUES ({values_sql}) "
      "ON CONFLICT (Name) DO NOTHING;\n"
    )

# %% [markdown]
# # Race tuples

# %%
#Race by name data found here https://dataverse.harvard.edu/dataset.xhtml?persistentId=doi:10.7910/DVN/SGKW0K
with open("race_tuples.txt", "w") as g:
    with open("/content/drive/MyDrive/databases_project/last_nameRaceProbs.tab", 'r') as f:
        race_list = f.readline().strip().split("\t")[1:]
        for line in f:
            line = line.strip().split("\t")
            values_to_check = line[1:]
            max_value_str = max(values_to_check)
            race = race_list[values_to_check.index(max_value_str)]
            name_literal = sql_literal(line[0].strip('"'))
            race_literal = sql_literal(race)

            g.write(
                f"INSERT INTO Race VALUES ({name_literal}, {race_literal}) "
                f"ON CONFLICT (Name) DO NOTHING;\n"
            )

# %%
# not enough race values attached to the names so gonna augment with a kaggle dataset
with open("race_tuples.txt", "a") as g:
    with open("/content/drive/MyDrive/databases_project/names-by-nationality.csv", 'r') as f:
        next(f)
        for line in f:
            line = line.strip().split(",")
            name = sql_literal(line[0])
            race = sql_literal(line[2])
            g.write(
                f"INSERT INTO Race VALUES ({name}, {race}) "
                f"ON CONFLICT (Name) DO NOTHING;\n"
            )

# %% [markdown]
# # Gender Tuples

# %%
author_names=set()
with open("/content/drive/MyDrive/databases_project/orcid_tuples.sql") as f:
    for line in f:
        line = str(line.split(",")[0].split("(")[1].strip("'").split(" ")[0]).lower()
        author_names.add(line)

# %%
author_names
# Out:
# {'zaka',
#  'marcus',
#  'remigio',
#  'gunter',
#  'sy',
#  'matt',
#  'xing-yuan',
#  'xiang',
#  'anselm',
#  'şule',
#  'menghua',
#  'rupal',
#  'wim',
#  'jens-christian',
#  'yan-gui',
#  'xiaozhen',
#  'usame',
#  'quan',
#  'rajkumar',
#  'yujia',
#  'haiyun',
#  'kashif',
#  'debotra',
#  'yu-ting',
#  'mo-kyung',
#  'haonan',
#  'shita',
#  'giovanni',
#  'sai',
#  'duoqian',
#  'zhaoyong',
#  'desi',
#  'danyang',
#  'chamila',
#  'mao',
#  'nouamane',
#  'ajit',
#  'maksym',
#  'ukadike',
#  'abooali',
#  'chase',
#  'yiyang',
#  'xinyu',
#  'yohei',
#  'catia',
#  'mariko',
#  'aurélie',
#  'supreet',
#  'iêda',
#  'jihong',
#  'karlijn',
#  'orlando',
#  'swetha',
#  'spiros',
#  'ouhara',
#  'sharma',
#  'soumyodeep',
#  'minyi',
#  'sato',
#  'yangyang',
#  'sen',
#  'dehui',
#  'cheikh',
#  'juliana',
#  'yeonjae',
#  'rita',
#  'saba',
#  'javad',
#  'shouhong',
#  'gharib',
#  'longjun',
#  'christine',
#  'leona',
#  'leigh',
#  'zhenmei',
#  'amogh',
#  'hikmet',
#  'siri',
#  'ermanno',
#  'kathleen',
#  'samira',
#  'yao-yue',
#  'itika',
#  'adile',
#  'xifan',
#  'tadaaki',
#  'golshan',
#  'nathalie',
#  'haichao',
#  'venla',
#  'fuchang',
#  'fazlul',
#  'chenxi',
#  'nayereh',
#  'kongfen',
#  'hong',
#  'elina',
#  'mario',
#  'tasneem',
#  'kayleb',
#  'kuidong',
#  'gheorghe',
#  'dongjie',
#  'zishan',
#  'changsheng',
#  'peyman',
#  'andrei',
#  'delfin',
#  'allison',
#  'bashir',
#  'jacob',
#  'pelin',
#  'ritu',
#  'rachael',
#  'qingbao',
#  'satoru',
#  'shiyi',
#  'sampathkumar',
#  'merve',
#  'eveline',
#  'jiaxu',
#  'yifan',
#  'mohamad',
#  'nazila',
#  'kai-uwe',
#  'yuchen',
#  'bhupinder',
#  'masami',
#  'lachlan',
#  'ananya',
#  'avery',
#  'sanghoon',
#  'haoran',
#  'ruo-nan',
#  'arghya',
#  'feng-shi',
#  'yuzhong',
#  'shilpi',
#  'de',
#  'ruiyu',
#  'jorge',
#  'shuhua',
#  'vicki',
#  'georgios',
#  'vineet',
#  'yuehong',
#  'jingyuan',
#  'murti',
#  'reema',
#  'huanhuan',
#  'brandie',
#  'haohao',
#  'e.',
#  'pouya',
#  'subham',
#  'huong',
#  'yumiko',
#  'mushap',
#  'jiaohao',
#  'paulo',
#  'janine',
#  'ae',
#  'yuhang',
#  'victoria',
#  'junayed',
#  'g.',
#  'vitoria',
#  'frits',
#  'suharika',
#  'ilayna',
#  'edith',
#  'xiner',
#  'abdullah',
#  'sagun',
#  'tuna',
#  'saravanan',
#  'coulombe',
#  'negar',
#  'dayang',
#  'xuanzhen',
#  'suhail',
#  'johan',
#  'guangyi',
#  'sasko',
#  'emi',
#  'sajjad',
#  'sabrina',
#  'titi',
#  'wenyan',
#  'elsa',
#  'itaru',
#  'mano',
#  'grant',
#  'uma',
#  'kei',
#  'kenyu',
#  'akm',
#  'flávia',
#  'wenbo',
#  'sawkar',
#  'bilal',
#  'roxanne',
#  'gernot',
#  'zhenhong',
#  'tomohiro',
#  'aida',
#  'tanya',
#  'chang-feng',
#  'roslin',
#  'roohi',
#  'jelle',
#  'jasper',
#  'rajan',
#  'fuyu',
#  'geetanjali',
#  'lilit',
#  'ilker',
#  'deepinder',
#  'simay',
#  'siti',
#  'stephan',
#  'jean-louis',
#  'şeyda',
#  'leszek',
#  'aku',
#  'liang-chih',
#  'jinyang',
#  'joydip',
#  'georg',
#  'padmasani',
#  'marc',
#  'genuario',
#  'herculina',
#  'rebecca',
#  'anny',
#  'himanshu',
#  'arijit',
#  'fred',
#  'jhun',
#  'jimmy',
#  'seyedali',
#  'bahadir',
#  'eisuke',
#  'chaoheng',
#  'nicolette',
#  'shujuan',
#  'fengping',
#  'khushboo',
#  'donghan',
#  'nakhoon',
#  'faraón',
#  'kentaro',
#  'amer',
#  'trang',
#  'niloufar',
#  'guanyu',
#  'ivana',
#  'muniba',
#  'saroj',
#  'renata',
#  'akshat',
#  'junkyu',
#  'bijit',
#  'stacey',
#  'roberto',
#  'fausto',
#  'luka',
#  'ernest',
#  'sergey',
#  'ramya',
#  'punam',
#  'wuman',
#  'angeliki',
#  'inge',
#  'junjie',
#  'helene',
#  'raneem',
#  'jesús',
#  'gülfem',
#  'matías',
#  'adity',
#  'garakani',
#  'huazhen',
#  'elliot',
#  'jayeeta',
#  'enass',
#  'bhushan',
#  'hoa',
#  'arjun',
#  'judith-elisa',
#  'shunzhang',
#  'uzma',
#  'zian',
#  'tian',
#  'ketsarin',
#  'weitong',
#  'neeraj',
#  'bernabas',
#  'suttida',
#  'jad',
#  'alvard',
#  'zidong',
#  'kairui',
#  'yanru',
#  'advances',
#  'yeqiu',
#  'junhui',
#  'gaia',
#  'anne-beatrice',
#  'jia-yu',
#  'janet',
#  'gilles',
#  'shixin',
#  'marta',
#  'zi-qi',
#  'adolfo',
#  'bitan',
#  'qiuyu',
#  'xuan-rong',
#  'shaoyi',
#  'nirupama',
#  'laure',
#  'yanrun',
#  'darragh',
#  'hung-xin',
#  'maowen',
#  'deekshitha',
#  'xumin',
#  'chuansheng',
#  'virginia',
#  'mert',
#  'shyan',
#  'yefeng',
#  'ya-lan',
#  'ranil',
#  'wentao',
#  'mustapha',
#  'jize',
#  'domitille',
#  'linh',
#  'lehao',
#  'tarun',
#  'xingyi',
#  'ruixin',
#  'ramachandran',
#  'erin',
#  'girish',
#  'abul',
#  'iftekhar',
#  'pui-in',
#  'pierre-yves',
#  'valerie',
#  'rodoljub',
#  'césar-aurelio',
#  'yun',
#  'hideyuki',
#  'monique',
#  'junyan',
#  'hasan',
#  'ngoc-quang',
#  'gu',
#  'wenshan',
#  'gerda',
#  'said',
#  'medani',
#  'hilde',
#  'kripa',
#  'asrina',
#  'junaid',
#  'pirdara',
#  'xiaoqing',
#  'bingce',
#  'zhu-jun',
#  'yongqing',
#  'ke-qin',
#  'mengdi',
#  'yaren',
#  'haijie',
#  'seung-whan',
#  'yanpei',
#  'md.',
#  'ashi',
#  'dae-won',
#  'jitian',
#  'yanyun',
#  'amélie',
#  'jérôme',
#  'tuba',
#  'åslaug',
#  'fatimah',
#  'shamima',
#  'alkida',
#  'xunyu',
#  'jianhao',
#  'manfred',
#  'jianming',
#  'saima',
#  'dongliang',
#  'julius',
#  'trude',
#  'steinar',
#  'yrjö',
#  'liujun',
#  'chunbo',
#  'yuanyuan',
#  'shuming',
#  'lidia',
#  'manel',
#  'benedikt',
#  'yukihiro',
#  'uri',
#  'frida',
#  'johnston',
#  'fujia',
#  'andrea',
#  'thi',
#  'mona',
#  'shodai',
#  'eric',
#  'ikuma',
#  'ka',
#  'mirela',
#  'cang-song',
#  'kirti',
#  'xiaotian',
#  'goro',
#  'jiao',
#  'jinxin',
#  'sikai',
#  'henry',
#  'jawad',
#  'belal',
#  'jiabin',
#  'ebele',
#  'ankang',
#  'mykola',
#  'nazuki',
#  'muruvvet',
#  'graciele',
#  'ani',
#  'yi-zhou',
#  'qianhua',
#  'cassidie',
#  'malcolm',
#  'eri',
#  'jessica',
#  'akihiro',
#  'hiromasa',
#  'fenlin',
#  'lindsay',
#  'olgierd',
#  'xiao-hu',
#  'malihe',
#  'waldemar',
#  'glynn',
#  'poornachandra',
#  'albert',
#  'magda',
#  'kawthar',
#  'riski',
#  'ronan',
#  'ravikumar',
#  'sihem',
#  'mengna',
#  'clare',
#  'travis',
#  'nazli',
#  'jakob',
#  'leo',
#  'seshu',
#  'lely',
#  'yingyan',
#  'janaka',
#  'sirui',
#  'adalton',
#  'junliang',
#  'snehasish',
#  'makhabbat',
#  'tonje',
#  'xuetao',
#  'xinxiang',
#  'rebeca',
#  'li-yong',
#  'insiyah',
#  'hanspeter',
#  'dongyu',
#  'hoe',
#  'kaijuan',
#  'genshu',
#  'annalisa',
#  'olaf',
#  'demet',
#  'srinivas',
#  'giuseppe',
#  'jung-an',
#  'mathilde',
#  'nathália',
#  'meghan',
#  'suryavardhani',
#  'yapeng',
#  'shuqing',
#  'ola',
#  'ling-hui',
#  'rajeev',
#  'ximena',
#  'xiaotong',
#  'surojit',
#  'jinjin',
#  'yohan',
#  'rajanikanta',
#  'josé',
#  'heejae',
#  'lily',
#  'juliane',
#  'marco',
#  'hiroto',
#  'haojie',
#  'aanchal',
#  'amirmehdi',
#  'na',
#  '海霞',
#  'maggie',
#  'wenxiang',
#  'yudong',
#  'sinem',
#  'ebenezer',
#  'vjaceslavs',
#  'kneeland',
#  'chi',
#  'klaus',
#  'kourous',
#  'joseph',
#  'delphine',
#  'chuhan',
#  'zhongjun',
#  'tara',
#  'jobanpreet',
#  'xiaomeng',
#  'wootton',
#  'hannah',
#  'ismail',
#  'hyagriv',
#  'hsiu-ni',
#  'debapratim',
#  'mingzhu',
#  'lingyi',
#  'yasmina',
#  'almeir',
#  'vinay',
#  'xiao-fei',
#  'xiangyu',
#  'xinyue',
#  'yun-peng',
#  'lennart',
#  'cicc',
#  'takuya',
#  'nurhidayah',
#  'genxu',
#  'masayasu',
#  'demiana',
#  'hongda',
#  'hermann',
#  'shaopei',
#  'ronghao',
#  'yutaka',
#  'changying',
#  'suresh',
#  'nanxing',
#  'longmei',
#  'calin',
#  'yajing',
#  'qing-biao',
#  'yanchao',
#  'junting',
#  'aitor',
#  'komang',
#  'yu-chuan',
#  'hülya',
#  'xuanang',
#  'chao',
#  'sadiq',
#  'piero',
#  'ruonan',
#  'mei-hua',
#  'prasanta',
#  'nobuaki',
#  'bita',
#  'akemi',
#  'yun-ru',
#  'andang',
#  'yunbin',
#  'syamsul',
#  'narjisse',
#  'shiyue',
#  'shibin',
#  'ziwei',
#  'xipeng',
#  'yılmaz',
#  'liv',
#  'yulin',
#  'jaclyn',
#  'dhananjay',
#  'branka',
#  'rajnish',
#  'zicheng',
#  'shiwei',
#  'himanish',
#  'preeti',
#  'arno',
#  'jianxun',
#  'hyunjoon',
#  'yuning',
#  'emily',
#  'limoran',
#  'peifu',
#  'shunli',
#  'malwina',
#  'bharati',
#  'yusheng',
#  'yile',
#  'tuo',
#  'najmeh',
#  'hemin',
#  'tushar',
#  'yosi',
#  'joy',
#  'debin',
#  'zihao',
#  's',
#  'di',
#  'moses',
#  'vahid',
#  'mst.',
#  'veena',
#  'carlo',
#  'irniza',
#  'zong',
#  'marcelo',
#  'florentino',
#  'weirong',
#  'dhaarani',
#  'evgenia',
#  'megha',
#  'wanni',
#  'yichen',
#  'andy',
#  'gaozhi',
#  'štefica',
#  'yuechi',
#  'göran',
#  'khoa',
#  'debapriya',
#  'aparna',
#  'raymond',
#  'suvasini',
#  'yuelei',
#  'oleksandr',
#  'sharon',
#  'shailendra',
#  'aniruddh',
#  'miljan',
#  'anniina',
#  'reyes',
#  'wei-cheng',
#  'price-haywood',
#  'zhongyun',
#  'dakuo',
#  'kun',
#  'sava',
#  'petter',
#  'melvin',
#  'songlin',
#  'guiqiu',
#  'winty',
#  'fajar',
#  'salar',
#  'pornlada',
#  'rui',
#  'xueyan',
#  'saïdou',
#  'guil',
#  'sanjeev',
#  'biao',
#  'ulrike',
#  'chang',
#  'tam',
#  'khadija',
#  'mahmoud',
#  'tianwei',
#  'nithin',
#  'thang',
#  'chunfeng',
#  'thanasis',
#  'han',
#  'heidi',
#  'hye-sook',
#  'allen',
#  'varsha',
#  'zhitong',
#  'dionysis',
#  'fuxin',
#  'zhaowei',
#  'toshiharu',
#  'junjun',
#  'hirok',
#  'meng',
#  'athanasios',
#  'willeke',
#  'maliheh',
#  'tomoko',
#  'kankana',
#  'q.',
#  'fouad',
#  'estelle',
#  'sukh',
#  'federica',
#  'petro',
#  'adesola',
#  'rizmy',
#  'arbnor',
#  'ameth',
#  'bradford',
#  'aryadevi',
#  'jan',
#  'ajay',
#  'xiaocong',
#  'carla',
#  'mitra',
#  'afaf',
#  'hidenao',
#  'torrin',
#  '求振',
#  'yudi',
#  'zhiping',
#  'francesco',
#  'taiji',
#  'vijayakumar',
#  'maxim',
#  'derya',
#  'kohei',
#  'zuoxin',
#  'anjun',
#  'ngo',
#  'haruhiko',
#  'hason',
#  'mengxue',
#  'aristomenis',
#  'minchi',
#  'xiangjing',
#  'laureano',
#  'subhash',
#  'xi',
#  'erberto',
#  'paraschos',
#  'xiaohan',
#  'marie-eve',
#  'verena',
#  'ranae',
#  'swapnil',
#  'kristof',
#  'jianguo',
#  'suzuki',
#  'cihan',
#  'irfan',
#  'kübra',
#  'shashikant',
#  'waqar',
#  'xingyuan',
#  'konstantin',
#  'rufei',
#  'yongle',
#  'setrida',
#  'hessam',
#  'moshe',
#  'jin-ling',
#  'haiwei',
#  'ma',
#  'lisangela',
#  'lailani',
#  'nur',
#  'peiyue',
#  'amonrat',
#  'raja',
#  'yajun',
#  'eun-hye',
#  'abdullateef',
#  'wanderson',
#  'manabu',
#  'xiao-lin',
#  'tongbao',
#  'shaun',
#  'lihui',
#  'najma',
#  'hamid',
#  'giulio',
#  'trevor',
#  'joana',
#  'shuang-qi',
#  'amina',
#  'ololade',
#  'xufei',
#  'bailin',
#  'ling',
#  'zequn',
#  'marcello',
#  'yezheng',
#  'yihai',
#  'shaodong',
#  'aditi',
#  'xueqian',
#  'yangchun',
#  'thais',
#  'chunlei',
#  'simón',
#  'netta',
#  'linan',
#  'shady',
#  'ulrika',
#  'jianyong',
#  'sengul',
#  'hidayat',
#  'dolly',
#  'jyothi',
#  'gonca',
#  'troels',
#  'x.',
#  'liangliang',
#  'lisa-sofie',
#  'zhifei',
#  'biancamaria',
#  'jialei',
#  'moises',
#  'beth',
#  'ruirui',
#  'jerry',
#  'christof',
#  'tahere',
#  'asem',
#  'yiwen',
#  'tarannum',
#  'shaowen',
#  'changsong',
#  'toshihiro',
#  'segundo',
#  'shraddha',
#  'le',
#  'marielle',
#  'willian',
#  'kadir',
#  'an',
#  'nicolò',
#  'mahesh',
#  'thandiwe',
#  'kuntal',
#  'tetsuro',
#  'mingyue',
#  'efe',
#  'premkumar',
#  'audina',
#  'tyrone',
#  'botao',
#  'xiaoyi',
#  'allan-hermann',
#  'jianchao',
#  'luan',
#  'dezhao',
#  'cybel',
#  'tianmi',
#  'xinjian',
#  'santiago',
#  'rui-jin',
#  'tsetsegsaikhan',
#  'xinying',
#  'keisuke',
#  'christos',
#  'lai',
#  'noureddin',
#  'abhinav',
#  'liang',
#  'wahyuni',
#  'tingsong',
#  'yanyu',
#  'rolika',
#  'biswanath',
#  'luis-rogelio',
#  'xiaona',
#  'shaw',
#  'nagavendra',
#  'iradj',
#  'roshini',
#  'aashish',
#  'miro',
#  'khaled',
#  'alisson',
#  'liana',
#  'hamidreza',
#  'shuhao',
#  'mac',
#  'kyu',
#  'abd.',
#  'shijun',
#  'xiu-hua',
#  'hoda',
#  'yinwei',
#  'vedran',
#  'thai',
#  'fawad',
#  'shen',
#  'viresh',
#  'zeng',
#  'laita',
#  'naotomo',
#  'wei-jun',
#  'kaycie',
#  'hong-wen',
#  'lyazat',
#  'guangwen',
#  'yuanjie',
#  'chiara',
#  'tianbao',
#  'xingzhou',
#  'i̇nci',
#  'bam',
#  'anjali',
#  'gauri',
#  'chunyan',
#  'filiz',
#  'fahimeh',
#  'stepan',
#  'berk',
#  'keita',
#  'galal',
#  'rajesh',
#  '佐藤',
#  'toru',
#  'thierry',
#  'hendy',
#  'ali',
#  'haslizatul',
#  'ahmed',
#  'anton',
#  'jamil',
#  'aqwin',
#  'tomoya',
#  'shotaro',
#  'sunita',
#  'sarang',
#  'hernan',
#  'zepeng',
#  'taiyang',
#  'dipak',
#  'gianluca',
#  'hegagi',
#  'hao',
#  'diletta',
#  'ece',
#  'suman',
#  'zhengguang',
#  'konstantinos',
#  'cate',
#  'siyuan',
#  'herlinah',
#  'r.',
#  'eun',
#  'shu-yu',
#  'you-yuan',
#  'qingbei',
#  'yunlong',
#  'venkata',
#  'enbo',
#  'alok',
#  'avital',
#  'erfan',
#  'chang-yu',
#  'chang-sheng',
#  'yajie',
#  'madison',
#  'early',
#  'justyna',
#  'zeng-guang',
#  'suneet',
#  'franco',
#  'akira',
#  'yinzhong',
#  'chunlin',
#  'liz',
#  'moren',
#  'awaisu',
#  'subhasis',
#  'jinyun',
#  'eleftherios',
#  'eyad',
#  'cary',
#  'nitin',
#  'jacqueline',
#  'fayha',
#  'dang',
#  'xiaozhou',
#  'shahenda',
#  'maher',
#  ...}

# %%
# data from: https://dataverse.harvard.edu/dataset.xhtml?persistentId=doi:10.7910/DVN/MSEGSJ
gender_data = "/content/drive/MyDrive/databases_project/gender_name_code.tsv"
gender_dict = {}
with open(gender_data, "r", encoding="utf-8") as f:

    next(f)  # skip header

    for line in f:
        parts = line.strip().split("\t")

        name = parts[0].strip().replace("'", "").replace('"', '').replace('\\', '')
        first_name = name.split(" ")[0]
        if not first_name in author_names:
            continue
        country = parts[1].strip().replace("\"", "")
        gender = parts[2].strip().replace("\"", "")
        if gender == "?":
            gender = "A"
        prob = float(parts[3].strip())
        #new name
        if name not in gender_dict.keys():
            gender_dict[name] = {}
            gender_dict[name][country] = [prob, gender]
        # New country for name
        elif country not in gender_dict[name].keys():
            gender_dict[name][country] = [prob, gender]
        # Higher prob for existing country
        else:
            if prob > gender_dict[name][country][0]:
                gender_dict[name][country] = [prob, gender]
            elif prob == gender_dict[name][country][0] and (prob == 0.5):
                gender_dict[name][country] = [1, "A"]

# %%
gender_dict.keys()
# Out:
# dict_keys(['s', 'a', 'a a', 'a aff', 'a ai', 'a an', 'a ang', 'a aron', 'a aya', 'a ba', 'a bai', 'a ban', 'a bang', 'a bao', 'a bei', 'a ben', 'a bi', 'a bian', 'a biao', 'a bin', 'a bing', 'a bo', 'a bu', 'a cai', 'a cang', 'a cao', 'a ce', 'a cen', 'a ceng', 'a cha', 'a chai', 'a chan', 'a chang', 'a chao', 'a chen', 'a cheng', 'a chi', 'a chong', 'a chou', 'a chu', 'a chuan', 'a chuang', 'a chun', 'a ci', 'a cong', 'a cui', 'a cun', 'a da', 'a dan', 'a dang', 'a dao', 'a de', 'a dele', 'a di', 'a dian', 'a diao', 'a die', 'a ding', 'a dong', 'a dou', 'a du', 'a duan', 'a dui', 'a dun', 'a duo', 'a e', 'a en', 'a er', 'a fa', 'a fan', 'a fang', 'a fei', 'a fen', 'a feng', 'a fu', 'a g', 'a ga', 'a gai', 'a gan', 'a gang', 'a gao', 'a ge', 'a gen', 'a geng', 'a gou', 'a gu', 'a guai', 'a guan', 'a guang', 'a gui', 'a gun', 'a guo', 'a hai', 'a han', 'a hannan', 'a hao', 'a he', 'a hei', 'a heng', 'a hong', 'a hou', 'a hu', 'a hua', 'a huai', 'a huan', 'a huang', 'a hui', 'a huo', 'a idah', 'a isha', 'a ishah', 'a j', 'a jana', 'a janae', 'a jay', 'a ji', 'a jia', 'a jian', 'a jiang', 'a jiao', 'a jie', 'a jin', 'a jing', 'a jiong', 'a jiu', 'a ju', 'a juan', 'a jun', 'a k i l', 'a ka', 'a kai', 'a kan', 'a kang', 'a ke', 'a keira', 'a kong', 'a kou', 'a kuai', 'a kuan', 'a kui', 'a kun', 'a la', 'a lah', 'a lai', 'a lan', 'a lang', 'a lao', 'a laura', 'a le', 'a lei', 'a lelia', 'a lerah', 'a lex ander', 'a li', 'a lian', 'a liang', 'a lie', 'a lin', 'a ling', 'a lisa', 'a liu', 'a liza', 'a lmos', 'a long', 'a lou', 'a lu', 'a luan', 'a lun', 'a luo', 'a lv', 'a mai', 'a man', 'a mang', 'a mao', 'a me', 'a mei', 'a men', 'a meng', 'a mer', 'a merie', 'a mi', 'a mian', 'a miao', 'a min', 'a ming', 'a mo', 'a mou', 'a mu', 'a na', 'a nai', 'a nak la', 'a nan', 'a nao', 'a nen', 'a neng', 'a nette', 'a ni', 'a nian', 'a niang', 'a ning', 'a niu', 'a niyah', 'a nong', 'a nu', 'a nuo', 'a nv', 'a ou', 'a pan', 'a pang', 'a pao', 'a pei', 'a peng', 'a pi', 'a pin', 'a ping', 'a pu', 'a qi', 'a qian', 'a qiang', 'a qiao', 'a qie', 'a qin', 'a qing', 'a qiong', 'a qiu', 'a qu', 'a quan', 'a que', 'a qun', 'a ran', 'a rang', 'a rao', 'a re', 'a ren', 'a ri', 'a rin', 'a ron', 'a rong', 'a ru', 'a rui', 'a run', 'a s m', 'a sa', 'a sai', 'a san', 'a sang', 'a sao', 'a se', 'a sen', 'a sha', 'a shan', 'a shang', 'a shao', 'a she', 'a shea', 'a shei', 'a shen', 'a sheng', 'a shi', 'a shou', 'a shu', 'a shuai', 'a shuang', 'a shui', 'a shun', 'a si', 'a song', 'a su', 'a sui', 'a sun', 'a suo', 'a ta', 'a tai', 'a tan', 'a tang', 'a tao', 'a te', 'a teng', 'a ti', 'a tian', 'a tiao', 'a tie', 'a tien', 'a ting', 'a tong', 'a tou', 'a treal', 'a tu', 'a tuan', 'a tuo', 'a wa', 'a wai', 'a wan', 'a wang', 'a wei', 'a wen', 'a wu', 'a xi', 'a xia', 'a xian', 'a xiang', 'a xiao', 'a xin', 'a xing', 'a xiong', 'a xiu', 'a xu', 'a xuan', 'a xue', 'a ya', 'a yan', 'a yang', 'a yao', 'a ye', 'a yeisha casey', 'a yi', 'a yin', 'a ying', 'a yong', 'a you', 'a yu', 'a yuan', 'a yue', 'a yun', 'a zai', 'a zan', 'a zao', 'a ze', 'a zeng', 'a zha', 'a zhan', 'a zhang', 'a zhao', 'a zhe', 'a zhen', 'a zheng', 'a zhi', 'a zhong', 'a zhou', 'a zhu', 'a zhuan', 'a zhuang', 'a zhuo', 'a zi', 'a zong', 'a zu', 'a zuan', 'a zuo', 'aaron', 'adele', 'aisha', 'ajay', 'alexander', 'amer', 'a.', 'aa', 'aa isha', 'aa ishah', 'aa ishah amina', 'aa niyah', 'aafreen', 'aakash', 'aamer', 'aamina', 'aaminah', 'aamir', 'aan', 'aanchal', 'aaron alberto', 'aaron alejandro', 'aaron alexander', 'aaron andres', 'aaron andrew', 'aaron antonio', 'aaron conrad', 'aaron daniel', 'aaron david', 'aaron dean', 'aaron eduardo', 'aaron enrique', 'aaron fernando', 'aaron francisco', 'aaron gabriel', 'aaron hagen', 'aaron isaac', 'aaron ismael', 'aaron james', 'aaron jamie', 'aaron javier', 'aaron jay', 'aaron jesus', 'aaron jnr', 'aaron joel', 'aaron john', 'aaron jordan', 'aaron jose', 'aaron joseph', 'aaron josue', 'aaron junior', 'aaron kane', 'aaron kenneth', 'aaron lee', 'aaron  ...

# %%
with open("Gender_tuples.txt", "w") as g:
    for key in gender_dict.keys():
        for country in gender_dict[key].keys():
            name_sql = sql_literal(key)
            country_sql = sql_literal(country)
            gender_sql = sql_literal(gender_dict[key][country][1])
            g.write(
                f"INSERT INTO Gender VALUES ({name_sql}, {country_sql}, {gender_sql});\n"
            )

# %%
# author_fullnames = set()

# for last, first in unique_authors:  # authors = your dict_keys(...)
#     if first:  # case: last name in first position, first name in second
#         full = f"{first.strip()} {last.strip()}"
#     else:      # case: first arg is already a full name
#         full = last.strip()

#     # Clean formatting
#     full = full.replace("  ", " ").strip()
#     author_fullnames.add(full)

# cleaned = {n for n in author_fullnames if n.strip()}
# print(cleaned)
# Out:
# {'Yanpei Wu', 'Jacek Banasiak', 'Wu Patimanabudu', 'Paola Galozzi', 'Hamida Seba', 'Yingyu Liu', 'Ralf Greiner', 'Kocherlakota Snigdha', 'Amit Agarwal', 'Linan Ye', 'Yang Zhiqing', 'Enbo Liu', 'Jennifer L. Bailit', 'Sheila Cyril', 'Wen-Ming Cao', 'Alireza Fereydooni', 'Muhammad Izzat Samir Abdul Jalil', 'Gillian Wylie', 'Tarun Goma', 'Fatemeh Karami Zarandi', 'Shinta Saito', 'Tania Serna', 'Nayia Cominos', 'Xinhui Quan', 'Ayşe İrem Özmen', 'Julio Ortega-Usobiaga', 'Angela Starkweather', 'Anthony Breitbach', 'Magda Mendez', 'Fangjian Zhu', 'N. Bolaños', 'S. C. Vetrivel', 'Jeferson Sandoval', 'Boto Simatupang', 'Lai Hui Charmaine Lee', 'Helen N Schwerdt', 'Hong J. Kim', 'Rebecca J. Post', 'Donghong Ning', 'Emily Weisberg', 'Zayira G. Alváez', 'Paulo Novais', 'Liang Hui', 'Anda M. Naciu', 'Rafal Madonski', 'Wan Nordin Wan Hussin', 'Yue Pan', 'Jianlun Xu', 'D. Charalambidis', 'Guixiu Shi', 'Elizabeth Tong', 'Y. Shao', 'Jin Fang', 'Thomas Klinger', 'Mei Wang', 'Pedro Pinto Santos', 'J. C. Juárez Tapia', 'Hongyu Bai', 'Muluken Zegeye Getie', 'Grigore Marian Pop', 'Khawar Siddiqui', 'Tom Bradshaw', 'Rasmus Stokholm', 'Jeremy Catania', 'Shyan Mascarenhas', 'Ista Meidarlina', 'Andrey Zharkov', 'Maria Kolona', 'Meng Qi', 'Tor Georg Jakobsen', 'Johanne G. Lilleøre', 'João Paulo André', 'Wang Jian', 'Arjun Neyyathala', 'Chandran, Siddharthan', 'Mikhail Lisyatnikov', 'V. Sivasankari', 'J. Galtier', 'Lin Zhang', 'Cem Eyerci', 'Aki Fukuda', 'Emily M. Melnick', 'Piero Vilcapoma', 'Chao Yong-sheng', 'Amar Prakash', 'Florence Rashidi', 'Saortua Marbun', 'Shen Yang', 'Yuanyuan Zhang', 'Sarah A. Sonsthagen', 'Laita Bokhari', 'Zhen Li', 'Shilpa Singhal', 'Yee Ling Lau', 'Nibedita S. Ray-Bennett', 'Daniela Meneses', 'Junhao Feng', 'Pooja Chebbi', 'Guillermo Rivas-Oliveros', 'Yanqi Chen', 'Teng Ma', 'Rajinikanth Maruthu', 'Ranjita Swain', 'Sahabuddin Sahabuddin', 'Lidong Wang', 'Montse Soriano Gabarró', 'Yaqing Wu', 'Nina Putuntean', 'Yu Gu', 'Rishitha Kunapareddy', 'Jeffrey Khan', 'Yair Neuman', 'Xinsong Zhong', 'Anastasia V. Kupryakova', 'Siyu Ji', 'Shun-Hsyung Chang', 'Ajay Kumar Mishra', 'Wasan Alhowaish', 'K. Varju', 'Siar Sarferaz', 'Jinhyeok Noh', 'Sylvia del Pilar Herrera Diaz', 'Seshu Kumar Damarla', 'Vera Rullens', 'Arpita Ghosh', 'G. Sagarkrishna', 'Piyush A. Kokate', 'Sun Mingyu', 'João Henriques', 'Jinglong Shi', 'Luh Made Mas Rusyati', 'Jianbing Yu', 'Ziya Şaka', 'Guangwen Li', 'Mohsen Karami Fath', 'Peter Y. A. Ryan', 'Jiang Nan', 'Sigrid Barrett', 'Mekonnen Getnet Yirak', 'Ana Paula Poeta Silva', 'F. Z. Elamri', 'Wu Lanbing', 'Wang Yi', 'Kamran Kheiralipour', 'Gargi Das', 'Kip Jones', 'Anelise Haukaas', 'Lei Xu', 'Honghui Wang', 'David M. Glick', 'Piali Mandal', 'Yuze Bai', 'Qing He', 'Reza Bagheri', 'Zhonghai Li', 'Julien Francken', 'Siobhán Healy-Cullen', 'Long, Xinyu', 'Avalos-Villatoro, Fabiola', 'Jeanine L. Marnewick', 'Rui Zhong', 'Li Yanjiao', 'Stathis Parcharidis', 'Amanda M. Root', 'Lavdrim Panxha', 'Wanzhen Hou', 'B. O. Naveen', 'Wendy Flores-Fuentes', 'Samira Sabzi', 'Radwa\xa0A. Awad', 'Zhihua Xia', 'Xiaoyong Qiao', 'Putu Chissa Purnama Dewi Rahjasa', 'I Blázquez', 'Krishna Kumar Gupta', 'Li Shuying', 'Aaron Rwodzi', 'Swati Mukherjee', 'Jun Xiong', 'Lisa S. Pijnacker', 'Johannes Hahmann', 'Chi Jin', 'N Steinberg', 'Patrick O. Ayiecho', 'Rebeca Puche-Navarro', 'Hafiz Syed Hamid Arshad', 'Zhang Jinman', 'Benjamin C. Hawthorne', 'Shyam Sundar Kesh', 'Fatemeh Fardsanei', 'Maha Zaki', 'Peng Chen', 'Wang Jiaoli', 'Yacob Abrehe Zereyesus', 'Tomoaki Washio', 'S.K. Kydyraliev', 'Preksha Yadav', 'Juan Wei', 'Sanweer Khatoon', 'Dee Bhakta', 'Danfeng Sun', 'Mike Kirby', 'Yuhao Chen', 'Sanjay Arora', 'Liu Jingwen', 'Alejandro De León Cuevas', 'Haocong Zhou', 'Steve H. Hanke', 'Liu Xiao-peng', 'Laux Miranda', 'Xilong Shan', 'Carlos Montoya', 'Mahesh R. Sanghavi', 'Wang Xiaoshang', 'Nada Ratković Kovačević', 'Qiang Yao', 'Julia Andersen', 'Wang Yichen', 'Sandra Torres', 'Huang Yanjuan', 'R‐Jun\xa0Frederick\xa0Avelino Gaspe', 'Joshua J.  ...

# %%
# gender_data = "/content/drive/MyDrive/databases_project/gender_name_code.tsv"
# gender_tuples = "gender_tuples.txt"
# names = set()

# with open(gender_data, "r", encoding="utf-8") as f, \
#      open(gender_tuples, "w", encoding="utf-8") as g:

#     next(f)  # skip header

#     for line in f:
#         parts = line.strip().split("\t")

#         name = parts[0].strip().replace("'", "").replace('"', '').replace('\\', '')
#         country = parts[1].strip().replace("\"", "")
#         gender = parts[2].strip().replace("\"", "")
#         names.add(name)

#         name_sql = sql_literal(name)
#         country_sql = sql_literal(country)
#         gender_sql = sql_literal(gender)

#         g.write(
#             f"INSERT INTO Gender VALUES ({name_sql}, {country_sql}, {gender_sql}) "
#             f"ON CONFLICT (Name) DO NOTHING;\n"
#         )

# print(names)
# Out:
# Buffered data was truncated after reaching the output size limit.

# %%
# # kaggle dataset with gender information

# gender_data = "/content/drive/MyDrive/databases_project/gender.csv"
# gender_tuples = "gender_tuples.txt"
# with open(gender_data, "r", encoding="utf-8") as f, \
#   open(gender_tuples, "w", encoding="utf-8") as g:
#   next(f)
#   for line in f:
#     parts = line.strip().split(",")
#     name = parts[0].strip()
#     gender = parts[1].strip()

#     name_sql = sql_literal(name)
#     gender_sql = sql_literal(gender)
#     g.write(
#         f"INSERT INTO Gender VALUES ({name_sql}, {gender_sql}) "
#         f"ON CONFLICT (Name) DO NOTHING;\n"
#     )

# %% [markdown]
# # Country Code Tuples

# %%
#Country code data
import kagglehub
import csv

data = kagglehub.dataset_download("juanumusic/countries-iso-codes")
data = data+"/wikipedia-iso-country-codes.csv"
with open("country_tuples.txt", "w") as g:
    with open(data, "r") as f:
        next(f)  # skip header
        reader = csv.reader(f)
        for codes in reader:
            codes = [codes[0], codes[1]]   # swapped the ordering (name, code)

            values_sql = ", ".join(sql_literal(v) for v in codes)
            g.write(
                f"INSERT INTO Countries VALUES ({values_sql}) "
                "ON CONFLICT (CountryCode) DO NOTHING;\n"
            )
# Out:
# Downloading from https://www.kaggle.com/api/v1/datasets/download/juanumusic/countries-iso-codes?dataset_version_number=1...
# 100%|██████████| 4.16k/4.16k [00:00<00:00, 9.03MB/s]
# Extracting files...

# %% [markdown]
# # DEFINE TABLES

# %%
institutions_table="""
CREATE TABLE IF NOT EXISTS Institutions (
    Name            VARCHAR(1000) PRIMARY KEY,
    Established     INTEGER,
    CountryCode     CHAR(2)
);

-- allows No affiliation provided as an option
INSERT INTO Institutions (Name, Established, CountryCode)
VALUES ('No Affiliation Provided', NULL, NULL)
ON CONFLICT (Name) DO NOTHING;
"""

author_table = """
CREATE TABLE IF NOT EXISTS Author (
    Name            VARCHAR(100) PRIMARY KEY,
    Affiliation     VARCHAR(1000),
    ORCID           CHAR(19),
    FOREIGN KEY (Affiliation) REFERENCES Institutions(Name)
);
"""

race_table= """
DROP TABLE Race;
CREATE TABLE IF NOT EXISTS Race (
    Name            VARCHAR(100) PRIMARY KEY,
    RaceLabel       VARCHAR(20),
    FOREIGN KEY (Name) REFERENCES Author(Name)
);
"""

journals_table="""
CREATE TABLE IF NOT EXISTS Journals (
    LongName        VARCHAR(100) PRIMARY KEY,
    ShortName       VARCHAR(100),
    Publisher       VARCHAR(100),
    ISSN            VARCHAR(10),
    eISSN           VARCHAR(10),
    Category        VARCHAR(50),
    Edition         VARCHAR(10),
    ImpactFactor    DECIMAL(5,1)
);
"""

articles_table="""
DROP TABLE Articles;
CREATE TABLE IF NOT EXISTS Articles (
    Title                   VARCHAR(300),
    Author                  VARCHAR(100),
    Author_Number           INTEGER,
    DOI                     VARCHAR(200),
    Publisher               VARCHAR(200),
    Score                   DECIMAL(5,1),
    URL                     VARCHAR(500),
    Published               VARCHAR(100),
    ISSN                    VARCHAR(20),
    Journal                 VARCHAR(1000),  -- jounral name
    References_Count        INTEGER,
    Is_Referenced_By_Count  INTEGER,
    FOREIGN KEY (Author) REFERENCES Author(Name),
    PRIMARY KEY (Title, Author_Number)
);
"""

country_table="""
CREATE TABLE IF NOT EXISTS Countries (
    Name            VARCHAR(100),
    CountryCode     CHAR(2) PRIMARY KEY
);
"""

gender_table="""
DROP TABLE Gender;
CREATE TABLE IF NOT EXISTS Gender (
    Name            VARCHAR(100),
    CountryCode     CHAR(2),
    GenderLabel     VARCHAR(20),
-- got rid of this foreign key because gender is based on the first name and author name is a full name
--     FOREIGN KEY (Name) REFERENCES Author(Name),
    FOREIGN KEY (CountryCode) REFERENCES Countries(CountryCode),
    PRIMARY KEY (Name, CountryCode)
);
"""
with open("tables.txt", "w") as f:
    f.write(author_table)
    f.write(race_table)
    f.write(gender_table)
    f.write(journals_table)
    f.write(articles_table)
    f.write(country_table)
    f.write(institutions_table)
